# %% [markdown]
# <center>
#   <font color="darkblue">
#     <span style="font-family: 'Times New Roman'; font-size: 22pt; line-height: 1.5;">
#       <h1><b>Projet Deep Learning</b></h1>
#     </span>
#   </font>
# </center>
#
# <center>
#   <font color="darkblue">
#     <span style="font-family: 'Times New Roman'; font-size: 16pt; line-height: 1.5;">
#       <h1><b>Prédiction des prix alimentaires en Mauritanie</b></h1>
#     </span>
#   </font>
# </center>
#
# <center>
#   <font color="darkblue">
#     <span style="font-family: 'Times New Roman'; font-size: 12pt; line-height: 1.5;">
#       <h1><i>Équipe de projet : 22032, 22117, 22240</i></h1>
#     </span>
#   </font>
# </center>

# %% [markdown]
# <div style="text-align:center">
#        <img src="food.png" style="width:60%; height:auto;" />
# </div>

# %% [markdown]
# <div style="background-color: #d1e7f2; padding: 20px; border-radius: 10px;">
#     <font color="navy">
#         <span style="font-family: 'Times New Roman'; font-size: 16pt;">
#             <b>I-1.&nbsp;&nbsp;&nbsp; <b> Introduction:</b>
#         </span>
#     </font>
# </div>

# %% [markdown]
#
#
# Ce projet vise à explorer et à analyser les données sur les prix des aliments en Mauritanie afin de développer un modèle de prédiction des séries temporelles. Les données fournissent des informations détaillées sur les prix des denrées alimentaires dans différentes régions administratives et marchés de la Mauritanie, ainsi que des détails sur les catégories de denrées alimentaires, les unités de mesure et les types de prix.
#
# L'objectif principal de ce projet est de développer un modèle prédictif basé sur des réseaux de neurones récurrents LSTM (Long Short-Term Memory) pour anticiper les variations futures des prix des aliments. En utilisant des techniques d'analyse exploratoire des données et de visualisation, nous chercherons à identifier les tendances, les saisons et les relations entre les variables.

# %% [markdown]
# <div style="background-color: #d1e7f2; padding: 20px; border-radius: 10px;">
#     <font color="navy">
#         <span style="font-family: 'Times New Roman'; font-size: 16pt;">
#             <b>I-2.&nbsp;&nbsp;&nbsp; <b> Contexte:</b>
#         </span>
#     </font>
# </div>

# %% [markdown]
# La Mauritanie, confrontée à des défis persistants en matière de sécurité alimentaire, cherche des solutions innovantes pour anticiper les fluctuations des prix des denrées alimentaires. Dans ce contexte, l'utilisation de modèles prédictifs tels que les réseaux de neurones récurrents à mémoire à long terme (LSTM) offre une approche prometteuse. Ce projet se concentre sur l'application de ces modèles pour prédire les prix des aliments en Mauritanie en utilisant les données fournies par le Programme alimentaire mondial (WFP) sur la période de 2003 à 2023. L'objectif est de fournir des outils prédictifs précieux pour les acteurs locaux afin de les aider à prendre des décisions éclairées en matière de politique alimentaire et de planification économique, contribuant ainsi à atténuer les risques liés à l'insécurité alimentaire et à promouvoir la stabilité économique dans la région.

# %% [markdown]
# <div style="background-color: #d1e7f2; padding: 20px; border-radius: 10px;">
#     <font color="navy">
#         <span style="font-family: 'Times New Roman'; font-size: 16pt;">
#             <b>II-1.&nbsp;&nbsp;&nbsp; Chargement des packages & Importation du Dataset
# </b>
#         </span>
#     </font>
# </div>

# %%
import pandas as pd
import numpy as np
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
from bokeh.tile_providers import get_provider, Vendors
from bokeh.models import ColumnDataSource, HoverTool, CategoricalColorMapper
from statsmodels.tsa.stattools import adfuller
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense
from keras.optimizers import Adam
from sklearn.metrics import mean_squared_error, r2_score


output_notebook()
import warnings
warnings.filterwarnings("ignore")
# Out:
# BokehDeprecationWarning: 'tile_providers module' was deprecated in Bokeh 3.0.0 and will be removed, use 'add_tile directly' instead.
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c56b75e7-abac-41b7-95ee-ea1d610c14a0">Loading BokehJS ...</span>
#     </div>

# %%
# Charger les données en ignorant la deuxième ligne
df = pd.read_csv("wfp_food_prices_mrt.csv", skiprows=[1])

# %%
# Afficher un aperçu des données
print("....................................")
df.head()
# Out:
# ....................................
#          date      admin1      admin2      market   latitude  longitude  \
# 0  2003-10-15  Nouakchott  Nouakchott  Nouakchott  18.119057 -16.022385
# 1  2003-10-15  Nouakchott  Nouakchott  Nouakchott  18.119057 -16.022385
# 2  2003-10-15  Nouakchott  Nouakchott  Nouakchott  18.119057 -16.022385
# 3  2003-10-15  Nouakchott  Nouakchott  Nouakchott  18.119057 -16.022385
# 4  2003-11-15  Nouakchott  Nouakchott  Nouakchott  18.119057 -16.022385
#
#               category        commodity unit priceflag pricetype currency  \
# 0   cereals and tubers  Rice (imported)   KG    actual    Retail      MRU
# 1   cereals and tubers      Wheat flour   KG    actual    Retail      MRU
# 2  meat, fish and eggs      Meat (beef)   KG    actual    Retail      MRU
# 3  meat, fish and eggs     Meat (camel)   KG    actual    Retail      MRU
# 4   cereals and tubers  Rice (imported)   KG    actual    Retail      MRU
#
#    price  usdprice
# 0  17.60    0.6782
# 1   8.80    0.3391
# 2   6.39    0.2462
# 3   6.24    0.2405
# 4  17.80    0.6736

# %% [markdown]
# <div style="background-color: #d1e7f2; padding: 20px; border-radius: 10px;">
#     <font color="navy">
#         <span style="font-family: 'Times New Roman'; font-size: 16pt;">
#             <b>II-2.&nbsp;&nbsp;&nbsp; <b> Presentation des variables :</b>
#         </span>
#     </font>
# </div>

# %% [markdown]
# | Variable   | Définition                                                                               |
# |------------|------------------------------------------------------------------------------------------|
# | date       | Date de l'enregistrement du prix (format: AAAA-MM-JJ)                                    |
# | admin1     | Région administrative de niveau 1 en Mauritanie                                          |
# | admin2     | Région administrative de niveau 2 en Mauritanie                                          |
# | market     | Nom du marché où le prix a été relevé                                                    |
# | latitude   | Latitude géographique du marché (en degrés décimaux)                                     |
# | longitude  | Longitude géographique du marché (en degrés décimaux)                                    |
# | category   | Catégorie de la denrée alimentaire                                                       |
# | commodity  | Nom de la denrée alimentaire                                                             |
# | unit       | Unité de mesure utilisée pour le prix (e.g., KG, L)                                      |
# | priceflag  | Type de prix (e.g., "actual" pour un prix réel)                                          |
# | pricetype  | Type de marché (e.g., "Retail" pour vente au détail)                                     |
# | currency   | Devise utilisée pour le prix (e.g., MRU pour Ouguiya mauritanienne)                      |
# | price      | Prix de la denrée alimentaire dans la devise locale                                      |
# | usdprice   | Prix de la denrée alimentaire en dollars américains (USD)                                |

# %% [markdown]
# <div style="background-color: #d1e7f2; padding: 20px; border-radius: 10px;">
#     <font color="navy">
#         <span style="font-family: 'Times New Roman'; font-size: 16pt;">
#             <b>II-3.&nbsp;&nbsp;&nbsp; <b> Description des Données :</b>
#         </span>
#     </font>
# </div>

# %% [markdown]
#   * *Source des données :*
# Les données utilisées dans ce projet proviennent de la base de données des prix alimentaires de la Mauritanie, fournies par le Programme Alimentaire Mondial (WFP). Les données couvrent diverses denrées alimentaires et leurs prix enregistrés sur une période de plusieurs années.

# %%
df.shape
# Out:
# (14319, 14)

# %%
# Convertir la colonne 'date' en type datetime
df['date'] = pd.to_datetime(df['date'])

# %%
# Comptage des valeurs dans la colonne 'admin1'
df['admin1'].value_counts()
# Out:
# admin1
# Brakna                2296
# Adrar                 1857
# Assaba                1569
# Nouakchott            1466
# Trarza                1335
# Guidimakha            1334
# Hodh El Gharbi        1312
# Dakhlet-Nouadhibou    1087
# Hodh Ech Chargi        876
# Gorgol                 768
# Tagant                 390
# Tiris-Zemmour           29
# Name: count, dtype: int64

# %%
# Afficher le nombre de valeurs uniques dans chaque colonne
print("Nombre de valeurs uniques dans chaque colonne :")
print(df.nunique())
# Out:
# Nombre de valeurs uniques dans chaque colonne :
# date          243
# admin1         12
# admin2         28
# market         34
# latitude       33
# longitude      34
# category        7
# commodity      26
# unit            5
# priceflag       2
# pricetype       1
# currency        1
# price        3469
# usdprice     7467
# dtype: int64

# %%
# Comptage des valeurs dans la colonne 'commodity'
df["commodity"].value_counts()
# Out:
# commodity
# Sugar                                             1727
# Oil (vegetable)                                   1723
# Rice (imported)                                   1670
# Rice (local)                                      1519
# Wheat                                             1490
# Sorghum (taghalit)                                1259
# Wheat flour                                        522
# Milk (powder)                                      470
# Beans (niebe)                                      454
# Maize (local)                                      368
# Pasta (macaroni)                                   326
# Wheat meal                                         310
# Livestock (goat, medium-sized male)                293
# Feed (rakhel)                                      289
# Livestock (sheep, medium-sized castrated male)     286
# Feed (flour)                                       264
# Meat (camel)                                       197
# Meat (beef)                                        197
# Livestock (cattle)                                 193
# Livestock (camel)                                  185
# Millet                                             170
# Couscous                                           158
# Sorghum (red)                                      106
# Straw                                               68
# Sorghum (r'haya)                                    49
# Feed (wheat bran)                                   26
# Name: count, dtype: int64

# %%
# Comptage des valeurs dans la colonne 'admin2'
df["admin2"].value_counts()
# Out:
# admin2
# Nouakchott       1466
# Tintane          1271
# Keur Macene      1125
# Ould Yenge       1119
# Barkeol          1117
# Nouadhibou       1087
# Ouadane           945
# M'Bagne           930
# Aoujeft           841
# Boghe             668
# Maghta Lahjar     630
# Amourj            630
# Kaedi             603
# Kankossa          391
# Moudjeria         335
# Selibaby          215
# Mederdra          150
# Bassikounou       141
# Nema              105
# M'Bout             83
# Maghama            82
# Atar               71
# Aleg               68
# Kiffa              61
# Rosso              60
# Tidjikja           55
# Aioun              41
# Zoueratt           29
# Name: count, dtype: int64

# %%
# Informations sur le DataFrame

print(df.info())
print("........................................")
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14319 entries, 0 to 14318
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       14319 non-null  datetime64[ns]
#  1   admin1     14319 non-null  object
#  2   admin2     14319 non-null  object
#  3   market     14319 non-null  object
#  4   latitude   14319 non-null  float64
#  5   longitude  14319 non-null  float64
#  6   category   14319 non-null  object
#  7   commodity  14319 non-null  object
#  8   unit       14319 non-null  object
#  9   priceflag  14319 non-null  object
#  10  pricetype  14319 non-null  object
#  11  currency   14319 non-null  object
#  12  price      14319 non-null  float64
#  13  usdprice   14319 non-null  float64
# dtypes: datetime64[ns](1), float64(4), object(9)
# memory usage: 1.5+ MB
# None
# ........................................
#                                 date      latitude     longitude  \
# count                          14319  14319.000000  14319.000000
# mean   2017-09-13 13:56:36.354493952     17.319529    -13.109982
# min              2003-10-15 00:00:00     14.770003    -17.048845
# 25%              2014-03-15 00:00:00     15.938907    -16.022385
# 50%              2018-06-15 00:00:00     16.595070    -13.059444
# 75%              2021-06-15 00:00:00     18.119057    -11.621376
# max              2023-12-15 00:00:00     22.688333     -5.516000
# std                              NaN      1.901925      2.618053
#
#               price      usdprice
# count  14319.000000  14319.000000
# mean     566.518486     15.554533
# min        2.800000      0.104600
# 25%       20.000000      0.621800
# 50%       28.000000      0.843900
# 75%       48.000000      1.384100
# max    40003.850000   1166.973300
# std     2544.205785     69.633330

# %% [markdown]
# <div style="background-color: #d1e7f2; padding: 20px; border-radius: 10px;">
#     <font color="navy">
#         <span style="font-family: 'Times New Roman'; font-size: 16pt;">
#             <b>III. &nbsp;&nbsp;&nbsp;  Exploration et Visualisation des Données :</b>
#         </span>
#     </font>
# </div>

# %% [markdown]
# - *Introduction* :
# La visualisation des données est cruciale pour comprendre les tendances, les saisons et les anomalies potentielles dans les séries temporelles des prix alimentaires. Les graphiques suivants offrent une vue d'ensemble des données et aident à identifier les principales caractéristiques des prix alimentaires en Mauritanie.

# %%
# Créer une figure pour la distribution des marchés
plt.figure(figsize=(8, 6))

# Utiliser seaborn pour créer un graphique en barres horizontales
ax = sns.countplot(data=df,
                   y="market",
                   palette="muted")

# Ajouter un titre au graphique
plt.title("Répartition des observations par marché")

# Calculer le nombre total d'observations
total = len(df["market"])

# Ajouter les pourcentages sur chaque barre
for p in ax.patches:
    # Calculer le pourcentage pour chaque barre
    percentage = '{:.1f}%'.format(100 * p.get_width() / total)
    # Définir la position x pour l'étiquette de pourcentage
    x = p.get_width() + 0.5
    # Définir la position y pour l'étiquette de pourcentage
    y = p.get_y() + p.get_height() / 2
    # Annoter le pourcentage sur le graphique
    ax.annotate(percentage, (x, y), ha='left', va='center')

# Sauvegarder le graphique sous forme d'image
plt.savefig('market_with_percentage.jpg')

# Afficher le graphique
plt.show()

# %% [markdown]
# * Les points de vente prélevés se présentent en majorité à Nouakchott, tandis que Rosso présente le plus faible nombre de points de vente.

# %%
 
# Créer une figure pour la distribution des produits alimentaires
plt.figure(figsize=(9, 7))

# Utiliser seaborn pour créer un graphique en barres horizontales
ax = sns.countplot(data=df,
                   y="commodity",
                   palette="muted")

# Ajouter un titre au graphique
plt.title("Répartition des observations par produit alimentaire")

# Calculer le nombre total d'observations
total = len(df["commodity"])

# Ajouter les pourcentages sur chaque barre
for p in ax.patches:
    # Calculer le pourcentage pour chaque barre
    percentage = '{:.1f}%'.format(100 * p.get_width() / total)
    # Définir la position x pour l'étiquette de pourcentage
    x = p.get_width() + 0.5
    # Définir la position y pour l'étiquette de pourcentage
    y = p.get_y() + p.get_height() / 2
    # Annoter le pourcentage sur le graphique
    ax.annotate(percentage, (x, y), ha='left', va='center')

# Sauvegarder le graphique sous forme d'image
plt.savefig('commodity_with_percentage.jpg')

# Afficher le graphique
plt.show()

# %% [markdown]
# * Le sucre, l'huile végétale et le riz, qu'ils soient locaux ou importés, occupent une part significative du marché mauritanien par rapport à d'autres produits.

# %%
# Convertir 'usdprice' en type numérique, en forçant les erreurs éventuelles
df['price'] = pd.to_numeric(df['price'], errors='coerce')

# Filtrer les données pour "Rice (imported)"
rice_df = df[df['commodity'] == 'Sugar'].copy()

# Extraire l'année de la date
rice_df['year'] = rice_df['date'].dt.year

# Calculer la moyenne des prix par année
average_price_per_year = rice_df.groupby('year')['price'].mean().reset_index()

# Visualiser les résultats
plt.figure(figsize=(10, 6))
sns.lineplot(data=average_price_per_year, x='year', y='price', marker='o')
plt.title("Évolution du prix de 'Sugar' par année")
plt.xlabel("Année")
plt.ylabel("Prix en MRO")
plt.grid(True)
plt.savefig('rice_price_evolution1.jpg')
plt.show()

# %% [markdown]
# * L'évolution du prix du sucre a connu une augmentation entre 2008 et 2014, suivie d'une baisse en 2015, puis une forte augmentation en 2021.

# %%
# Convertir 'usdprice' en type numérique, en forçant les erreurs éventuelles
df['price'] = pd.to_numeric(df['price'], errors='coerce')

# Filtrer les données pour "Rice (imported)"
rice_df = df[df['commodity'] == 'Oil (vegetable)'].copy()

# Extraire l'année de la date
rice_df['year'] = rice_df['date'].dt.year

# Calculer la moyenne des prix par année
average_price_per_year = rice_df.groupby('year')['price'].mean().reset_index()

# Visualiser les résultats
plt.figure(figsize=(10, 6))
sns.lineplot(data=average_price_per_year, x='year', y='price', marker='o')
plt.title("Évolution du prix de 'Oil (vegetable)' par année")
plt.xlabel("Année")
plt.ylabel("Prix en MRO")
plt.grid(True)
plt.savefig('rice_price_evolution3.jpg')
plt.show()

# %% [markdown]
# * Le prix de l'huile végétale a présenté une évolution quasi constante au cours des années, suivie d'une forte augmentation à partir de 2020 due a la pandemie du corona.

# %%
 
# Convertir 'price' en type numérique, en forçant les erreurs éventuelles
df['price'] = pd.to_numeric(df['price'], errors='coerce')

# Filtrer les données pour "Rice (imported)" et "Rice (local)"
rice_df = df[df['commodity'].isin(['Rice (imported)', 'Rice (local)'])].copy()

# Extraire l'année de la date
rice_df.loc[:, 'year'] = rice_df['date'].dt.year

# Calculer la moyenne des prix par année et par type de riz
average_price_per_year = rice_df.groupby(['year', 'commodity'])['price'].mean().reset_index()

# S'assurer que les années sont traitées comme des entiers
average_price_per_year['year'] = average_price_per_year['year'].astype(int)

# Visualiser les résultats
plt.figure(figsize=(12, 6))
sns.lineplot(data=average_price_per_year, x='year', y='price', hue='commodity', marker='o')
plt.title("Évolution des prix de 'Rice (imported)' et 'Rice (local)' par année")
plt.xlabel("Année")
plt.ylabel("Prix en MRO")
plt.legend(title='Commodity')
plt.xticks(average_price_per_year['year'].unique())  # Assurez-vous que seules les années distinctes sont affichées
plt.grid(True)
plt.savefig('rice_price_comparison.jpg')
plt.show()

# %% [markdown]
# * Le prix du riz importé a toujours été supérieur à celui du riz local au cours des annees .

# %%
 

# Convertir 'usdprice' en type numérique, en forçant les erreurs éventuelles
df['price'] = pd.to_numeric(df['price'], errors='coerce')

# Filtrer les données pour "Rice (imported)" et "Rice (local)"
rice_df = df[df['commodity'].isin(['Meat (beef)', 'Meat (camel)'])].copy()

# Extraire l'année de la date
rice_df['year'] = rice_df['date'].dt.year

# Calculer la moyenne des prix par année et par type de riz
average_price_per_year = rice_df.groupby(['year', 'commodity'])['price'].mean().reset_index()

# S'assurer que les années sont traitées comme des entiers
average_price_per_year['year'] = average_price_per_year['year'].astype(int)

# Visualiser les résultats
plt.figure(figsize=(12, 6))
sns.lineplot(data=average_price_per_year, x='year', y='price', hue='commodity', marker='o')
plt.title("Évolution des prix de 'Meat (beef)' et 'Meat (camel)' par année")
plt.xlabel("Année")
plt.ylabel("Prix en MRO")
plt.legend(title='Commodity')
plt.xticks(average_price_per_year['year'].unique())  # Assurez-vous que seules les années distinctes sont affichées
plt.grid(True)
plt.savefig('rice_price_comparison.jpg')
plt.show()

# %% [markdown]
# * L'évolution des prix de la viande de bœuf et de chameau au fil des années est presque identique, ce qui souligne l'importance de la viande dans l'alimentation mauritanienne.

# %%
# Convertir la colonne 'date' en datetime si ce n'est pas déjà fait
df['date'] = pd.to_datetime(df['date'])

# Filtrer les données pour l'année 2019
df_2019 = df[df['date'].dt.year == 2019]

# Filtrer les données pour "Sugar"
df_sugar = df_2019[df_2019['commodity'] == 'Sugar']

# Calculer les prix moyens par région admin2 pour "Sugar"
prix_moyens_sugar = df_sugar.groupby(['admin2', 'latitude', 'longitude'])['price'].mean().reset_index()

# Ajouter une colonne 'year' avec la valeur 2019
prix_moyens_sugar['year'] = 2019

# Fonction pour convertir les coordonnées latitude et longitude en coordonnées Web Mercator
def wgs84_to_web_mercator(df, lon="longitude", lat="latitude"):
    k = 6378137
    df["x"] = df[lon] * (k * np.pi / 180.0)
    df["y"] = np.log(np.tan((90 + df[lat]) * np.pi / 360.0)) * k
    return df

# Appliquer la conversion sur les données
prix_moyens_sugar = wgs84_to_web_mercator(prix_moyens_sugar)

# Créer une source de données pour Bokeh
source = ColumnDataSource(prix_moyens_sugar)

# Initialiser la carte
p = figure(title="Prix moyen de Sugar en 2019", x_axis_type="mercator", y_axis_type="mercator", 
           width=800, height=600)
tile_provider = get_provider(Vendors.CARTODBPOSITRON)
p.add_tile(tile_provider)

# Ajouter des cercles pour chaque point de donnée
p.circle(x="x", y="y", size=10, fill_color="blue", fill_alpha=0.8, source=source)

# Ajouter des outils de survol
hover = HoverTool()
hover.tooltips = [("Région", "@admin2"), ("Prix moyen (MRU)", "@price{0.2f}"), ("Année", "@year")]
p.add_tools(hover)

# Afficher la carte
show(p)
# Out:
#   <div id="f377bc1a-f25c-440a-a94d-be9da7d384af" data-root-id="p1004" style="display: contents;"></div>

# %%
# Convertir la colonne 'date' en datetime si ce n'est pas déjà fait
df['date'] = pd.to_datetime(df['date'])

# Filtrer les données pour l'année 2019
df_2019 = df[df['date'].dt.year == 2019]

# Filtrer les données pour "Oil (vegetable)"
df_oil = df_2019[df_2019['commodity'] == 'Oil (vegetable)']

# Calculer les prix moyens par région admin2 pour "Oil (vegetable)"
prix_moyens_oil = df_oil.groupby(['admin2', 'latitude', 'longitude'])['price'].mean().reset_index()

# Ajouter une colonne 'year' avec la valeur 2019
prix_moyens_oil['year'] = 2019

# Fonction pour convertir les coordonnées latitude et longitude en coordonnées Web Mercator
def wgs84_to_web_mercator(df, lon="longitude", lat="latitude"):
    k = 6378137
    df["x"] = df[lon] * (k * np.pi / 180.0)
    df["y"] = np.log(np.tan((90 + df[lat]) * np.pi / 360.0)) * k
    return df

# Appliquer la conversion sur les données
prix_moyens_oil = wgs84_to_web_mercator(prix_moyens_oil)

# Créer une source de données pour Bokeh
source = ColumnDataSource(prix_moyens_oil)

# Initialiser la carte
p = figure(title="Prix moyen de Oil (vegetable) en 2019", x_axis_type="mercator", y_axis_type="mercator", 
           width=800, height=600)
tile_provider = get_provider(Vendors.CARTODBPOSITRON)
p.add_tile(tile_provider)

# Ajouter des cercles pour chaque point de donnée
p.circle(x="x", y="y", size=10, fill_color="blue", fill_alpha=0.8, source=source)

# Ajouter des outils de survol
hover = HoverTool()
hover.tooltips = [("Région", "@admin2"), ("Prix moyen (MRU)", "@price{0.2f}"), ("Année", "@year")]
p.add_tools(hover)

# Afficher la carte
show(p)
# Out:
#   <div id="f34898b1-4bfa-4e2d-b90b-31869fb55f40" data-root-id="p1060" style="display: contents;"></div>

# %%
# Convertir la colonne 'date' en datetime
df['date'] = pd.to_datetime(df['date'])

# Filtrer les données pour l'année 2019
df_2023 = df[df['date'].dt.year == 2019]

# Filtrer les données pour "Rice (imported)" et "Rice (local)"
df_rice = df_2023[df_2023['commodity'].isin(['Rice (imported)', 'Rice (local)'])]

# Calculer les prix moyens par région admin2 pour chaque type de riz
prix_moyens_rice = df_rice.groupby(['admin2', 'commodity', 'latitude', 'longitude'])['price'].mean().reset_index()

# Ajouter une colonne 'year' avec la valeur 2019
prix_moyens_rice['year'] = 2019

# Fonction pour convertir les coordonnées latitude et longitude en coordonnées Web Mercator
def wgs84_to_web_mercator(df, lon="longitude", lat="latitude"):
    k = 6378137
    df["x"] = df[lon] * (k * np.pi / 180.0)
    df["y"] = np.log(np.tan((90 + df[lat]) * np.pi / 360.0)) * k
    return df

# Appliquer la conversion sur les données
prix_moyens_rice = wgs84_to_web_mercator(prix_moyens_rice)

# Créer une source de données pour Bokeh
source = ColumnDataSource(prix_moyens_rice)

# Initialiser la carte
p = figure(title="Prix moyen de Rice (imported) et Rice (local) en 2019", x_axis_type="mercator", y_axis_type="mercator", 
           width=800, height=600)
tile_provider = get_provider(Vendors.CARTODBPOSITRON)
p.add_tile(tile_provider)

# Ajouter des cercles pour chaque type de riz avec des couleurs différentes
color_mapper = CategoricalColorMapper(factors=['Rice (imported)', 'Rice (local)'], palette=['blue', 'green'])
p.circle(x="x", y="y", size=10, fill_color={'field': 'commodity', 'transform': color_mapper}, fill_alpha=0.8, source=source)

# Ajouter des outils de survol
hover = HoverTool()
hover.tooltips = [("Région", "@admin2"), ("Type de riz", "@commodity"), ("Prix moyen (MRU)", "@price{0.2f}"), ("Année", "@year")]
p.add_tools(hover)

# Afficher la carte
show(p)
# Out:
#   <div id="da8dfc9c-50ea-4e35-9e2d-7675b63c9a19" data-root-id="p1116" style="display: contents;"></div>

# %% [markdown]
# * La corrélation entre la distance géographique et les prix observée pour tous les produits, avec une tendance à des prix plus élevés dans les régions éloignées de Nouakchott, suggère des coûts logistiques plus élevés ou une demande accrue dans les zones urbaines. Ces observations soulignent l'importance de politiques de distribution adaptées pour garantir l'accessibilité des produits de base dans toutes les régions du pays.
# * Dans le 2 villes(Kaedi,et M'Bagne ) il y a que que le riz importé, ce qui peut etre justifiée par leurs proximité géographique avec le Sénégal, un important producteur de riz.
# * Le riz importé reste toujours plus cher souligne une dynamique persistante dans le marché.
# * Cette remarque souligne également l'importance de soutenir et d'encourager la production locale de riz. En favorisant le développement de l'agriculture locale, les autorités peuvent contribuer à réduire la dépendance vis-à-vis des importations, ce qui pourrait potentiellement conduire à une baisse des prix et à une plus grande sécurité alimentaire pour la population mauritanienne.

# %% [markdown]
# <div style="background-color: #d1e7f2; padding: 20px; border-radius: 10px;">
#     <font color="navy">
#         <span style="font-family: 'Times New Roman'; font-size: 16pt;">
#             <b>IV. &nbsp;&nbsp;&nbsp;  Prétraitement des données :</b>
#         </span>
#     </font>
# </div>

# %% [markdown]
# - *Introduction :* Le prétraitement des données est une étape importante dans l'analyse de données. Avant de pouvoir appliquer des modèles ou des techniques d'analyse avancés, il est essentiel de préparer les données de manière adéquate. Cette section se concentre sur les étapes préliminaires visant à rendre les données prêtes pour l'analyse et à garantir leur qualité.

# %% [markdown]
# <div style="background-color: #d1e7f2; padding: 20px; border-radius: 10px;">
#     <font color="navy">
#         <span style="font-family: 'Times New Roman'; font-size: 16pt;">
#             <b>IV.-1 &nbsp;&nbsp;&nbsp;  Test de stationnarité :</b>
#         </span>
#     </font>
# </div>

# %% [markdown]
# - *Introduction :* La stationnarité est une propriété importante des séries temporelles qui indique que les caractéristiques statistiques des données restent constantes dans le temps. Tester la stationnarité des séries temporelles est crucial car de nombreux modèles et techniques d'analyse des séries temporelles supposent que les données sont stationnaires. Cette partie vise à évaluer la stationnarité des données et à prendre les mesures nécessaires pour les rendre stationnaires si besoin est.

# %%
# Convertir la colonne 'date' en datetime
df['date'] = pd.to_datetime(df['date'])

# Produits spécifiés
produits_specifies = ['Sugar', 'Oil (vegetable)', 'Rice (imported)', 'Rice (local)', 'Meat (camel)', 'Meat (beef)']

# Calculer la moyenne des prix par jour et produit
df_moyennes = df.groupby(['date', 'commodity'])['price'].mean().reset_index()

# Filtrer les données pour les produits spécifiés
df_produits = df_moyennes[df_moyennes['commodity'].isin(produits_specifies)]

# Créer une fonction pour tester la stationnarité
def test_stationarity(df, product_name):
    result = adfuller(df['price'])
    print(f'Test de stationnarité pour le produit {product_name}:')
    print('ADF Statistic:', result[0])
    print('p-value:', result[1])
    print('Critical Values:')
    for key, value in result[4].items():
        print(f'\t{key}: {value}')
    print('\n')

# Tester la stationnarité pour chaque produit et visualiser les séries temporelles
plt.figure(figsize=(14, 10))
for i, produit in enumerate(produits_specifies):
    df_produit = df_produits[df_produits['commodity'] == produit]
    
    # Appliquer le test ADF
    print(f"Stationnarité pour {produit}")
    test_stationarity(df_produit, produit)
    
    # Tracer les séries temporelles
    plt.subplot(3, 2, i+1)
    plt.plot(df_produit['date'], df_produit['price'], label=produit)
    plt.title(f'Prix moyen de {produit} par jour')
    plt.xlabel('Date')
    plt.ylabel('Prix')
    plt.legend(loc='best')

plt.tight_layout()
plt.show()
# Out:
# Stationnarité pour Sugar
# Test de stationnarité pour le produit Sugar:
# ADF Statistic: -0.9607983433362531
# p-value: 0.767292442731325
# Critical Values:
# 	1%: -3.4654311561944873
# 	5%: -2.8769570530458792
# 	10%: -2.574988319755886
#
#
# Stationnarité pour Oil (vegetable)
# Test de stationnarité pour le produit Oil (vegetable):
# ADF Statistic: -1.5894976365253255
# p-value: 0.4888670383443275
# Critical Values:
# 	1%: -3.466398230774071
# 	5%: -2.8773796387256514
# 	10%: -2.575213838610586
#
#
# Stationnarité pour Rice (imported)
# Test de stationnarité pour le produit Rice (imported):
# ADF Statistic: -0.5865086528083452
# p-value: 0.8740014704315165
# Critical Values:
# 	1%: -3.4578942529658563
# 	5%: -2.8736593200231484
# 	10%: -2.573228767361111
#
#
# Stationnarité pour Rice (local)
# Test de stationnarité pour le produit Rice (local):
# ADF Statistic: 0.4616749454310371
# p-value: 0.9836604914570902
# Critical Values:
# 	1%: -3.4668001583460613
# 	5%: -2.8775552336674317
# 	10%: -2.5753075498128246
#
#
# Stationnarité pour Meat (camel)
# Test de stationnarité pour le produit Meat (camel):
# ADF Statistic: -1.4864764866446432
# p-value: 0.5401903054388553
# Critical Values:
# 	1%: -3.464337030867007
# 	5%: -2.876478799035722
# 	10%: -2.574733103221565
#
#
# Stationnarité pour Meat (beef)
# Test de stationnarité pour le produit Meat (beef):
# ADF Statistic: -1.4673441268651242
# p-value: 0.5495994771520452
# Critical Values:
# 	1%: -3.464161278384219
# 	5%: -2.876401960790147
# 	10%: -2.5746921001665974

# %% [markdown]
# <div style="background-color: #d1e7f2; padding: 20px; border-radius: 10px;">
#     <font color="navy">
#         <span style="font-family: 'Times New Roman'; font-size: 16pt;">
#             <b>IV.-2 &nbsp;&nbsp;&nbsp;  Résultats des tests de stationnarité :</b>
#         </span>
#     </font>
# </div>

# %% [markdown]
# 1. **Sugar**
#    - ADF Statistic: -0.9607983433362531
#    - p-value: 0.767292442731325
#    - Critical Values:
#      - 1%: -3.4654311561944873
#      - 5%: -2.8769570530458792
#      - 10%: -2.574988319755886
#
#    **Commentaire**: La série de prix du sucre n'est pas stationnaire. La statistique ADF est supérieure à la valeur critique à 5% et la p-value est bien supérieure à 0.05.
#
# 2. **Oil (vegetable)**
#    - ADF Statistic: -1.5894976365253255
#    - p-value: 0.4888670383443275
#    - Critical Values:
#      - 1%: -3.466398230774071
#      - 5%: -2.8773796387256514
#      - 10%: -2.575213838610586
#
#    **Commentaire**: La série de prix de l'huile végétale n'est pas stationnaire. La statistique ADF est supérieure à la valeur critique à 5% et la p-value est supérieure à 0.05.
#
# 3. **Rice (imported)**
#    - ADF Statistic: -0.5865086528083452
#    - p-value: 0.8740014704315165
#    - Critical Values:
#      - 1%: -3.4578942529658563
#      - 5%: -2.8736593200231484
#      - 10%: -2.573228767361111
#
#    **Commentaire**: La série de prix du riz importé n'est pas stationnaire. La statistique ADF est bien supérieure à la valeur critique à 5% et la p-value est très supérieure à 0.05.
#
# 4. **Rice (local)**
#    - ADF Statistic: 0.4616749454310371
#    - p-value: 0.9836604914570902
#    - Critical Values:
#      - 1%: -3.4668001583460613
#      - 5%: -2.8775552336674317
#      - 10%: -2.5753075498128246
#
#    **Commentaire**: La série de prix du riz local n'est pas stationnaire. La statistique ADF est supérieure à la valeur critique à 5% et la p-value est très supérieure à 0.05.
#
# 5. **Meat (camel)**
#    - ADF Statistic: -1.4864764866446432
#    - p-value: 0.5401903054388553
#    - Critical Values:
#      - 1%: -3.464337030867007
#      - 5%: -2.876478799035722
#      - 10%: -2.574733103221565
#
#    **Commentaire**: La série de prix de la viande de chameau n'est pas stationnaire. La statistique ADF est supérieure à la valeur critique à 5% et la p-value est supérieure à 0.05.
#
# 6. **Meat (beef)**
#    - ADF Statistic: -1.4673441268651242
#    - p-value: 0.5495994771520452
#    - Critical Values:
#      - 1%: -3.464161278384219
#      - 5%: -2.876401960790147
#      - 10%: -2.5746921001665974
#
#    **Commentaire**: La série de prix de la viande de bœuf n'est pas stationnaire. La statistique ADF est supérieure à la valeur critique à 5% et la p-value est supérieure à 0.05.
#
# ##### *Conclusion :*
#
# Aucune des séries de prix des produits analysés (Sugar, Oil (vegetable), Rice (imported), Rice (local), Meat (camel), Meat (beef)) n'est stationnaire. Cela signifie que les séries temporelles de ces prix ont tendance à varier au fil du temps, et des transformations ou des méthodes de différenciation pourraient être nécessaires pour les rendre stationnaires avant d'appliquer des modèles de prévision ou des analyses de séries temporelles.

# %% [markdown]
# #### -  Justification des résultats :
#
# 1. **Sugar**
#    - La non-stationnarité des prix du sucre peut être attribuée à la dépendance aux importations et aux fluctuations des prix internationaux. Les variations dans les coûts de transport et les politiques commerciales influencent également les prix.
#
# 2. **Oil (vegetable)**
#    - Les prix de l'huile végétale montrent une non-stationnarité due à la volatilité des marchés internationaux et à la dépendance aux importations. Les variations saisonnières dans la production et les coûts de transport jouent également un rôle.
#
# 3. **Rice (imported)**
#    - La non-stationnarité des prix du riz importé reflète la dépendance de la Mauritanie aux importations pour répondre à la demande locale. Les fluctuations des prix internationaux, les coûts de transport et les variations des taux de change influencent les prix.
#
# 4. **Rice (local)**
#    - Les prix du riz local ne sont pas stationnaires en raison des variations saisonnières de la production, des conditions climatiques changeantes et des techniques agricoles. La dépendance aux conditions météorologiques et aux infrastructures locales affecte également les prix.
#
# 5. **Meat (camel)**
#    - La non-stationnarité des prix de la viande de chameau peut être attribuée aux variations saisonnières de l'offre, à la demande fluctuante et aux conditions climatiques qui affectent le bétail. Les facteurs culturels et les fêtes religieuses peuvent également influencer les prix.
#
# 6. **Meat (beef)**
#    - Les prix de la viande de bœuf montrent une non-stationnarité en raison des variations de l'offre, des coûts de production, et des conditions climatiques affectant le bétail. Les fluctuations de la demande et les pratiques commerciales locales jouent également un rôle.
#
# ##### *Conclusion :*
#
# Les prix des produits analysés (Sugar, Oil (vegetable), Rice (imported), Rice (local), Meat (camel), Meat (beef)) ne sont pas stationnaires, reflétant une multitude de facteurs économiques, climatiques, et commerciaux propres à la Mauritanie. Ces facteurs incluent la dépendance aux importations, les variations saisonnières, les fluctuations des marchés internationaux et les conditions climatiques locales, rendant les prix de ces produits volatils et variables au fil du temps.

# %% [markdown]
# <div style="background-color: #d1e7f2; padding: 20px; border-radius: 10px;">
#     <font color="navy">
#         <span style="font-family: 'Times New Roman'; font-size: 16pt;">
#             <b>IV.-3 &nbsp;&nbsp;&nbsp;    Différenciation des séries :</b>
#         </span>
#     </font>
# </div>

# %% [markdown]
# - L'approche de rendre les séries stationnaires avant d'appliquer un modèle LSTM permet de mieux capturer les fluctuations temporelles et d'améliorer la capacité du modèle à apprendre les tendances à long terme de manière plus efficace.
# - Bien que rendre les séries stationnaires puisse améliorer la performance des modèles LSTM en facilitant l'apprentissage des tendances à long terme, ce n'est pas toujours nécessaire, notamment si le modèle est capable de capturer efficacement les tendances et les fluctuations dans les données brutes.
# - Le modèle LSTM est conçu pour capturer les dépendances à long terme dans les séries temporelles, y compris les tendances et les fluctuations. Cependant, son efficacité dépend de divers facteurs, tels que la taille et la qualité des données, la complexité du modèle, et la capacité de l'algorithme d'apprentissage à généraliser à partir des données fournies. Dans certains cas, les données brutes peuvent contenir suffisamment d'informations pour que le modèle LSTM puisse les exploiter efficacement sans avoir besoin de les rendre stationnaires. Cependant, dans d'autres cas, la stationnarisation peut améliorer la capacité du modèle à apprendre les motifs sous-jacents et à faire des prédictions plus précises.

# %% [markdown]
# * Quelques methodes pour rendre les séries temporelles stationnaires :
#
# 1. Différenciation : Calculer la différence entre les valeurs successives pour éliminer les tendances.
# 2. Transformation logarithmique : Appliquer une transformation logarithmique pour stabiliser la variance.
# 3. Désaisonnalisation : Supprimer les variations saisonnières en soustrayant la moyenne mobile saisonnière.

# %%
df_produits.head()
# Out:
#         date        commodity  price
# 0 2003-10-15      Meat (beef)   6.39
# 1 2003-10-15     Meat (camel)   6.24
# 2 2003-10-15  Rice (imported)  17.60
# 4 2003-11-15      Meat (beef)   6.50
# 5 2003-11-15     Meat (camel)   6.53

# %%
# Produits spécifiés
produits_specifies = ["Sugar", "Oil (vegetable)", "Rice (imported)", "Rice (local)", "Meat (camel)", "Meat (beef)"]

# Filtrer les données pour les produits spécifiés
df_produits = df[df['commodity'].isin(produits_specifies)]

# %%
df_produits.tail()
# Out:
#             date          admin1       admin2  market   latitude  longitude  \
# 14299 2023-12-15  Hodh El Gharbi      Tintane    Twil  15.520000 -10.130000
# 14304 2023-12-15          Trarza  Keur Macene  Ndiago  16.171314 -16.500429
# 14305 2023-12-15          Trarza  Keur Macene  Ndiago  16.171314 -16.500429
# 14314 2023-12-15          Trarza  Keur Macene  Ndiago  16.171314 -16.500429
# 14317 2023-12-15          Trarza  Keur Macene  Ndiago  16.171314 -16.500429
#
#                  category        commodity unit  priceflag pricetype currency  \
# 14299        oil and fats  Oil (vegetable)    L  aggregate    Retail      MRU
# 14304  cereals and tubers  Rice (imported)   KG  aggregate    Retail      MRU
# 14305  cereals and tubers     Rice (local)   KG  aggregate    Retail      MRU
# 14314  miscellaneous food            Sugar   KG  aggregate    Retail      MRU
# 14317        oil and fats  Oil (vegetable)    L  aggregate    Retail      MRU
#
#        price  usdprice
# 14299  59.79    1.5046
# 14304  40.00    1.0065
# 14305  30.00    0.7549
# 14314  40.00    1.0065
# 14317  74.86    1.8838

# %%
df_produits.shape
# Out:
# (7033, 14)

# %%
# Calculer la moyenne des prix par jour pour chaque produit
df_moyennes_jour = df_produits.groupby(['date', 'commodity'])['price'].mean().reset_index()
# Définir une fonction pour tester la stationnarité
def test_stationarity(series):
    result = adfuller(series)
    print('Test de stationnarité :')
    print('ADF Statistic:', result[0])
    print('p-value:', result[1])
    print('Critical Values:')
    for key, value in result[4].items():
        print(f'\t{key}: {value}')
    print('\n')

# %%
# Appliquer une différenciation pour rendre les séries stationnaires si nécessaire
for produit in produits_specifies:
    prix_produit = df_moyennes_jour[df_moyennes_jour['commodity'] == produit]['price']
    result = adfuller(prix_produit)
    if result[1] > 0.05:
        diff = prix_produit.diff().dropna()
        print(f'Stationnarité après différenciation pour {produit}:')
        test_stationarity(diff)
# Out:
# Stationnarité après différenciation pour Sugar:
# ADF Statistic: -13.257353251636214
# p-value: 8.53460551066981e-25
# Stationnarité après différenciation pour Oil (vegetable):
# ADF Statistic: -8.282190648000011
# p-value: 4.4885630297663014e-13
# Stationnarité après différenciation pour Rice (imported):
# ADF Statistic: -15.967615651619832
# p-value: 7.063039069079486e-29
# Stationnarité après différenciation pour Rice (local):
# ADF Statistic: -6.878171312458675
# p-value: 1.456359095593797e-09
# Stationnarité après différenciation pour Meat (camel):
# ADF Statistic: -15.656044333451229
# p-value: 1.5749519674396348e-28
# Stationnarité après différenciation pour Meat (beef):
# ADF Statistic: -9.616046271294818
# p-value: 1.7593159001089229e-16

# %% [markdown]
# * Les différences entre les tests de stationnarité avant et après différenciation sont les suivantes :
#
# Avant la différenciation :
# - Les séries ont des valeurs d'ADF Statistic négatives mais proches de zéro.
# - Les p-values sont élevées, indiquant que les séries ne sont pas stationnaires.
# - Les valeurs d'ADF Statistic se situent généralement au-dessus des seuils critiques.
#
# Après la différenciation :
# - Les valeurs d'ADF Statistic sont fortement négatives.
# - Les p-values sont très faibles voire proches de zéro, indiquant une forte stationnarité.
# - Les valeurs d'ADF Statistic sont inférieures aux seuils critiques, confirmant la stationnarité des séries après différenciation.
#
# En résumé, la différenciation a permis de rendre les séries stationnaires, comme en témoignent les valeurs significativement plus faibles des p-values et des valeurs d'ADF Statistic après l'opération.

# %% [markdown]
# <div style="background-color: #d1e7f2; padding: 20px; border-radius: 10px;">
#     <font color="navy">
#         <span style="font-family: 'Times New Roman'; font-size: 16pt;">
#             <b>V. &nbsp;&nbsp;&nbsp;  Modélisation avec LSTM :</b>
#         </span>
#     </font>
# </div>

# %%
# Convertir la colonne 'date' en datetime
df['date'] = pd.to_datetime(df['date'])

# Produits spécifiés
produits_specifies = ['Sugar', 'Oil (vegetable)', 'Rice (imported)', 'Rice (local)', 'Meat (camel)', 'Meat (beef)']

# Calculer la moyenne des prix par jour et produit
df_moyennes = df.groupby(['date', 'commodity'])['price'].mean().reset_index()

# Filtrer les données pour les produits spécifiés
df_produits = df_moyennes[df_moyennes['commodity'].isin(produits_specifies)]

# Préparation des données pour LSTM
def prepare_data(df, produit, time_steps=10):
    df_produit = df[df['commodity'] == produit].copy()
    df_produit.set_index('date', inplace=True)
    values = df_produit['price'].values.reshape(-1, 1)
    
    # Normalisation des données
    scaler = MinMaxScaler(feature_range=(0, 1))
    values_scaled = scaler.fit_transform(values)
    
    # Création des séquences
    X, y = [], []
    for i in range(len(values_scaled) - time_steps):
        X.append(values_scaled[i:(i + time_steps), 0])
        y.append(values_scaled[i + time_steps, 0])
    
    X, y = np.array(X), np.array(y)
    X = X.reshape((X.shape[0], X.shape[1], 1))
    
    return X, y, scaler

# Construire et entraîner le modèle LSTM
def train_lstm(X, y, epochs=50, batch_size=32):
    model = Sequential()
    model.add(LSTM(50, return_sequences=True, input_shape=(X.shape[1], X.shape[2])))
    model.add(LSTM(50))
    model.add(Dense(1))
    model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')
    model.fit(X, y, epochs=epochs, batch_size=batch_size, verbose=2, shuffle=False)
    return model 

# Faire des prédictions
def predict(model, X, scaler):
    predictions = model.predict(X)
    predictions = scaler.inverse_transform(predictions)
    return predictions

# Visualiser les résultats
def plot_predictions(dates, actual, predicted, produit):
    plt.figure(figsize=(12, 6))
    plt.plot(dates, actual, color='blue', label='Actual')
    plt.plot(dates, predicted, color='red', linestyle='--', label='Predicted')
    plt.title(f'Actual vs Predicted Prices for {produit}')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

# Fonction pour prédire le prix futur pour une date donnée
def predict_future_price(produit, future_date, df_produits, time_steps=10):
    future_date = pd.to_datetime(future_date)
    
    # Préparer les données pour le produit
    X, y, scaler = prepare_data(df_produits, produit, time_steps)
    model = train_lstm(X, y, epochs=50, batch_size=32)

    # Calculer le nombre de jours à prédire
    last_date = df_produits[df_produits['commodity'] == produit]['date'].max()
    days_to_predict = (future_date - last_date).days
    
    if days_to_predict <= 0:
        raise ValueError("Future date must be after the last date in the dataset.")
    
    # Utiliser la dernière séquence pour prédire plusieurs jours dans le futur
    last_sequence = X[-1].reshape((1, time_steps, 1))
    
    for _ in range(days_to_predict):
        future_price_scaled = model.predict(last_sequence)
        last_sequence = np.append(last_sequence[:, 1:, :], future_price_scaled.reshape(1, 1, 1), axis=1)

    future_price = scaler.inverse_transform(future_price_scaled)
    return future_price[0][0]


# Paramètres
time_steps = 10

for produit in produits_specifies:
    X, y, scaler = prepare_data(df_produits, produit, time_steps)
    model = train_lstm(X, y, epochs=50, batch_size=32)
    
    # Faire des prédictions
    predictions = predict(model, X, scaler)
    
    # Comparer avec les données réelles
    dates = df_produits[df_produits['commodity'] == produit]['date'][time_steps:]
    actual_prices = df_produits[df_produits['commodity'] == produit]['price'][time_steps:]
    
    # Visualisation
    plot_predictions(dates, actual_prices, predictions, produit)

    # Evaluation du modèle
    mse = mean_squared_error(actual_prices, predictions)
    print(f'Mean Squared Error for {produit}: {mse}')
# Out:
# Epoch 1/50
# 6/6 - 7s - 1s/step - loss: 0.1684
# Epoch 2/50
# 6/6 - 0s - 17ms/step - loss: 0.0193
# Epoch 3/50
# 6/6 - 0s - 13ms/step - loss: 0.0322
# Epoch 4/50
# 6/6 - 0s - 13ms/step - loss: 0.0158
# Epoch 5/50
# 6/6 - 0s - 13ms/step - loss: 0.0137
# Epoch 6/50
# 6/6 - 0s - 13ms/step - loss: 0.0100
# Epoch 7/50
# 6/6 - 0s - 14ms/step - loss: 0.0093
# Epoch 8/50
# 6/6 - 0s - 14ms/step - loss: 0.0110
# Epoch 9/50
# 6/6 - 0s - 17ms/step - loss: 0.0094
# Epoch 10/50
# 6/6 - 0s - 14ms/step - loss: 0.0086
# Epoch 11/50
# 6/6 - 0s - 14ms/step - loss: 0.0082
# Epoch 12/50
# 6/6 - 0s - 14ms/step - loss: 0.0086
# Epoch 13/50
# 6/6 - 0s - 15ms/step - loss: 0.0083
# Epoch 14/50
# 6/6 - 0s - 15ms/step - loss: 0.0080
# Epoch 15/50
# 6/6 - 0s - 16ms/step - loss: 0.0079
# Epoch 16/50
# 6/6 - 0s - 16ms/step - loss: 0.0080
# Epoch 17/50
# 6/6 - 0s - 15ms/step - loss: 0.0079
# Epoch 18/50
# 6/6 - 0s - 15ms/step - loss: 0.0078
# Epoch 19/50
# 6/6 - 0s - 14ms/step - loss: 0.0077
# Epoch 20/50
# 6/6 - 0s - 15ms/step - loss: 0.0077
# Epoch 21/50
# 6/6 - 0s - 16ms/step - loss: 0.0076
# Epoch 22/50
# 6/6 - 0s - 15ms/step - loss: 0.0076
# Epoch 23/50
# 6/6 - 0s - 16ms/step - loss: 0.0076
# Epoch 24/50
# 6/6 - 0s - 15ms/step - loss: 0.0075
# Epoch 25/50
# 6/6 - 0s - 16ms/step - loss: 0.0074
# Epoch 26/50
# 6/6 - 0s - 17ms/step - loss: 0.0074
# Epoch 27/50
# 6/6 - 0s - 15ms/step - loss: 0.0073
# Epoch 28/50
# 6/6 - 0s - 15ms/step - loss: 0.0073
# Epoch 29/50
# 6/6 - 0s - 15ms/step - loss: 0.0072
# Epoch 30/50
# 6/6 - 0s - 15ms/step - loss: 0.0072
# Epoch 31/50
# 6/6 - 0s - 16ms/step - loss: 0.0071
# Epoch 32/50
# 6/6 - 0s - 16ms/step - loss: 0.0070
# Epoch 33/50
# 6/6 - 0s - 16ms/step - loss: 0.0070
# Epoch 34/50
# 6/6 - 0s - 16ms/step - loss: 0.0069
# Epoch 35/50
# 6/6 - 0s - 15ms/step - loss: 0.0069
# Epoch 36/50
# 6/6 - 0s - 15ms/step - loss: 0.0068
# Epoch 37/50
# 6/6 - 0s - 17ms/step - loss: 0.0067
# Epoch 38/50
# 6/6 - 0s - 16ms/step - loss: 0.0067
# Epoch 39/50
# 6/6 - 0s - 15ms/step - loss: 0.0066
# Epoch 40/50
# 6/6 - 0s - 16ms/step - loss: 0.0065
# Epoch 41/50
# 6/6 - 0s - 16ms/step - loss: 0.0065
# Epoch 42/50
# 6/6 - 0s - 17ms/step - loss: 0.0064
# Epoch 43/50
# 6/6 - 0s - 16ms/step - loss: 0.0063
# Epoch 44/50
# 6/6 - 0s - 14ms/step - loss: 0.0063
# Epoch 45/50
# 6/6 - 0s - 15ms/step - loss: 0.0062
# Epoch 46/50
# 6/6 - 0s - 16ms/step - loss: 0.0061
# Epoch 47/50
# 6/6 - 0s - 15ms/step - loss: 0.0061
# Epoch 48/50
# 6/6 - 0s - 16ms/step - loss: 0.0060
# Epoch 49/50
# 6/6 - 0s - 14ms/step - loss: 0.0059
# Epoch 50/50
# 6/6 - 0s - 17ms/step - loss: 0.0059
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step
# Mean Squared Error for Sugar: 4.165535018318007
# Epoch 1/50
# 6/6 - 5s - 872ms/step - loss: 0.1025
# Epoch 2/50
# 6/6 - 0s - 15ms/step - loss: 0.0180
# Epoch 3/50
# 6/6 - 0s - 15ms/step - loss: 0.0239
# Epoch 4/50
# 6/6 - 0s - 16ms/step - loss: 0.0218
# Epoch 5/50
# 6/6 - 0s - 16ms/step - loss: 0.0164
# Epoch 6/50
# 6/6 - 0s - 20ms/step - loss: 0.0129
# Epoch 7/50
# 6/6 - 0s - 17ms/step - loss: 0.0107
# Epoch 8/50
# 6/6 - 0s - 18ms/step - loss: 0.0114
# Epoch 9/50
# 6/6 - 0s - 19ms/step - loss: 0.0109
# Epoch 10/50
# 6/6 - 0s - 18ms/step - loss: 0.0107
# Epoch 11/50
# 6/6 - 0s - 18ms/step - loss: 0.0101
# Epoch 12/50
# 6/6 - 0s - 23ms/step - loss: 0.0101
# Epoch 13/50
# 6/6 - 0s - 18ms/step - loss: 0.0101
# Epoch 14/50
# 6/6 - 0s - 24ms/step - loss: 0.0100
# Epoch 15/50
# 6/6 - 0s - 21ms/step - loss: 0.0099
# Epoch 16/50
# 6/6 - 0s - 19ms/step - loss: 0.0098
# Epoch 17/50
# 6/6 - 0s - 20ms/step - loss: 0.0098
# Epoch 18/50
# 6/6 - 0s - 19ms/step - loss: 0.0097
# Epoch 19/50
# 6/6 - 0s - 19ms/step - loss: 0.0096
# Epoch 20/50
# 6/6 - 0s - 19ms/step - loss: 0.0096
# Epoch 21/50
# 6/6 - 0s - 18ms/step - loss: 0.0095
# Epoch 22/50
# 6/6 - 0s - 19ms/step - loss: 0.0094
# Epoch 23/50
# 6/6 - 0s - 19ms/step - loss: 0.0093
# Epoch 24/50
# 6/6 - 0s - 18ms/step - loss: 0.0092
# Epoch 25/50
# 6/6 - 0s - 17ms/step - loss: 0.0091
# Epoch 26/50
# 6/6 - 0s - 35ms/step - loss: 0.0090
# Epoch 27/50
# 6/6 - 0s - 16ms/step - loss: 0.0089
# Epoch 28/50
# 6/6 - 0s - 15ms/step - loss: 0.0088
# Epoch 29/50
# 6/6 - 0s - 15ms/step - loss: 0.0087
# Epoch 30/50
# 6/6 - 0s - 16ms/step - loss: 0.0086
# Epoch 31/50
# 6/6 - 0s - 15ms/step - loss: 0.0085
# Epoch 32/50
# 6/6 - 0s - 15ms/step - loss: 0.0084
# Epoch 33/50
# 6/6 - 0s - 16ms/step - loss: 0.0083
# Epoch 34/50
# 6/6 - 0s - 22ms/step - loss: 0.0082
# Epoch 35/50
# 6/6 - 0s - 18ms/step - loss: 0.0080
# Epoch 36/50
# 6/6 - 0s - 17ms/step - loss: 0.0079
# Epoch 37/50
# 6/6 - 0s - 16ms/step - loss: 0.0078
# Epoch 38/50
# 6/6 - 0s - 34ms/step - loss: 0.0076
# Epoch 39/50
# 6/6 - 0s - 21ms/step - loss: 0.0075
# Epoch 40/50
# 6/6 - 0s - 17ms/step - loss: 0.0073
# Epoch 41/50
# 6/6 - 0s - 17ms/step - loss: 0.0072
# Epoch 42/50
# 6/6 - 0s - 18ms/step - loss: 0.0070
# Epoch 43/50
# 6/6 - 0s - 16ms/step - loss: 0.0068
# Epoch 44/50
# 6/6 - 0s - 16ms/step - loss: 0.0066
# Epoch 45/50
# 6/6 - 0s - 17ms/step - loss: 0.0064
# Epoch 46/50
# 6/6 - 0s - 17ms/step - loss: 0.0062
# Epoch 47/50
# 6/6 - 0s - 16ms/step - loss: 0.0060
# Epoch 48/50
# 6/6 - 0s - 15ms/step - loss: 0.0058
# Epoch 49/50
# 6/6 - 0s - 15ms/step - loss: 0.0056
# Epoch 50/50
# 6/6 - 0s - 16ms/step - loss: 0.0054
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step
# Mean Squared Error for Oil (vegetable): 15.726379803749998
# Epoch 1/50
# 8/8 - 7s - 847ms/step - loss: 0.1337
# Epoch 2/50
# 8/8 - 0s - 17ms/step - loss: 0.0068
# Epoch 3/50
# 8/8 - 0s - 17ms/step - loss: 0.0187
# Epoch 4/50
# 8/8 - 0s - 18ms/step - loss: 0.0111
# Epoch 5/50
# 8/8 - 0s - 17ms/step - loss: 0.0056
# Epoch 6/50
# 8/8 - 0s - 20ms/step - loss: 0.0064
# Epoch 7/50
# 8/8 - 0s - 19ms/step - loss: 0.0049
# Epoch 8/50
# 8/8 - 0s - 19ms/step - loss: 0.0047
# Epoch 9/50
# 8/8 - 0s - 21ms/step - loss: 0.0045
# Epoch 10/50
# 8/8 - 0s - 20ms/step - loss: 0.0045
# Epoch 11/50
# 8/8 - 0s - 22ms/step - loss: 0.0044
# Epoch 12/50
# 8/8 - 0s - 20ms/step - loss: 0.0045
# Epoch 13/50
# 8/8 - 0s - 17ms/step - loss: 0.0045
# Epoch 14/50
# 8/8 - 0s - 19ms/step - loss: 0.0047
# Epoch 15/50
# 8/8 - 0s - 21ms/step - loss: 0.0048
# Epoch 16/50
# 8/8 - 0s - 26ms/step - loss: 0.0053
# Epoch 17/50
# 8/8 - 0s - 24ms/step - loss: 0.0058
# Epoch 18/50
# 8/8 - 0s - 23ms/step - loss: 0.0069
# Epoch 19/50
# 8/8 - 0s - 23ms/step - loss: 0.0089
# Epoch 20/50
# 8/8 - 0s - 22ms/step - loss: 0.0095
# Epoch 21/50
# 8/8 - 0s - 26ms/step - loss: 0.0120
# Epoch 22/50
# 8/8 - 0s - 22ms/step - loss: 0.0081
# Epoch 23/50
# 8/8 - 0s - 22ms/step - loss: 0.0077
# Epoch 24/50
# 8/8 - 0s - 24ms/step - loss: 0.0050
# Epoch 25/50
# 8/8 - 0s - 24ms/step - loss: 0.0047
# Epoch 26/50
# 8/8 - 0s - 21ms/step - loss: 0.0043
# Epoch 27/50
# 8/8 - 0s - 22ms/step - loss: 0.0042
# Epoch 28/50
# 8/8 - 0s - 22ms/step - loss: 0.0042
# Epoch 29/50
# 8/8 - 0s - 21ms/step - loss: 0.0042
# Epoch 30/50
# 8/8 - 0s - 19ms/step - loss: 0.0042
# Epoch 31/50
# 8/8 - 0s - 18ms/step - loss: 0.0042
# Epoch 32/50
# 8/8 - 0s - 19ms/step - loss: 0.0042
# Epoch 33/50
# 8/8 - 0s - 19ms/step - loss: 0.0042
# Epoch 34/50
# 8/8 - 0s - 25ms/step - loss: 0.0042
# Epoch 35/50
# 8/8 - 0s - 24ms/step - loss: 0.0042
# Epoch 36/50
# 8/8 - 0s - 22ms/step - loss: 0.0042
# Epoch 37/50
# 8/8 - 0s - 22ms/step - loss: 0.0042
# Epoch 38/50
# 8/8 - 0s - 25ms/step - loss: 0.0042
# Epoch 39/50
# 8/8 - 0s - 38ms/step - loss: 0.0042
# Epoch 40/50
# 8/8 - 0s - 20ms/step - loss: 0.0042
# Epoch 41/50
# 8/8 - 0s - 20ms/step - loss: 0.0042
# Epoch 42/50
# 8/8 - 0s - 18ms/step - loss: 0.0042
# Epoch 43/50
# 8/8 - 0s - 17ms/step - loss: 0.0044
# Epoch 44/50
# 8/8 - 0s - 17ms/step - loss: 0.0044
# Epoch 45/50
# 8/8 - 0s - 17ms/step - loss: 0.0047
# Epoch 46/50
# 8/8 - 0s - 17ms/step - loss: 0.0049
# Epoch 47/50
# 8/8 - 0s - 17ms/step - loss: 0.0058
# Epoch 48/50
# 8/8 - 0s - 16ms/step - loss: 0.0070
# Epoch 49/50
# 8/8 - 0s - 19ms/step - loss: 0.0085
# Epoch 50/50
# 8/8 - 0s - 16ms/step - loss: 0.0118
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001D9D8300220> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 153ms/step
# Mean Squared Error for Rice (imported): 2.919820234166602
# Epoch 1/50
# 6/6 - 5s - 901ms/step - loss: 0.1716
# Epoch 2/50
# 6/6 - 0s - 14ms/step - loss: 0.0218
# Epoch 3/50
# 6/6 - 0s - 14ms/step - loss: 0.0225
# Epoch 4/50
# 6/6 - 0s - 14ms/step - loss: 0.0193
# Epoch 5/50
# 6/6 - 0s - 14ms/step - loss: 0.0136
# Epoch 6/50
# 6/6 - 0s - 15ms/step - loss: 0.0085
# Epoch 7/50
# 6/6 - 0s - 16ms/step - loss: 0.0052
# Epoch 8/50
# 6/6 - 0s - 15ms/step - loss: 0.0071
# Epoch 9/50
# 6/6 - 0s - 15ms/step - loss: 0.0060
# Epoch 10/50
# 6/6 - 0s - 15ms/step - loss: 0.0049
# Epoch 11/50
# 6/6 - 0s - 15ms/step - loss: 0.0039
# Epoch 12/50
# 6/6 - 0s - 16ms/step - loss: 0.0040
# Epoch 13/50
# 6/6 - 0s - 17ms/step - loss: 0.0039
# Epoch 14/50
# 6/6 - 0s - 16ms/step - loss: 0.0038
# Epoch 15/50
# 6/6 - 0s - 16ms/step - loss: 0.0037
# Epoch 16/50
# 6/6 - 0s - 15ms/step - loss: 0.0037
# Epoch 17/50
# 6/6 - 0s - 18ms/step - loss: 0.0037
# Epoch 18/50
# 6/6 - 0s - 23ms/step - loss: 0.0037
# Epoch 19/50
# 6/6 - 0s - 27ms/step - loss: 0.0037
# Epoch 20/50
# 6/6 - 0s - 22ms/step - loss: 0.0037
# Epoch 21/50
# 6/6 - 0s - 21ms/step - loss: 0.0037
# Epoch 22/50
# 6/6 - 0s - 20ms/step - loss: 0.0037
# Epoch 23/50
# 6/6 - 0s - 21ms/step - loss: 0.0037
# Epoch 24/50
# 6/6 - 0s - 19ms/step - loss: 0.0037
# Epoch 25/50
# 6/6 - 0s - 18ms/step - loss: 0.0037
# Epoch 26/50
# 6/6 - 0s - 19ms/step - loss: 0.0037
# Epoch 27/50
# 6/6 - 0s - 18ms/step - loss: 0.0037
# Epoch 28/50
# 6/6 - 0s - 18ms/step - loss: 0.0037
# Epoch 29/50
# 6/6 - 0s - 18ms/step - loss: 0.0037
# Epoch 30/50
# 6/6 - 0s - 18ms/step - loss: 0.0037
# Epoch 31/50
# 6/6 - 0s - 18ms/step - loss: 0.0036
# Epoch 32/50
# 6/6 - 0s - 19ms/step - loss: 0.0036
# Epoch 33/50
# 6/6 - 0s - 18ms/step - loss: 0.0036
# Epoch 34/50
# 6/6 - 0s - 18ms/step - loss: 0.0036
# Epoch 35/50
# 6/6 - 0s - 19ms/step - loss: 0.0036
# Epoch 36/50
# 6/6 - 0s - 20ms/step - loss: 0.0036
# Epoch 37/50
# 6/6 - 0s - 19ms/step - loss: 0.0036
# Epoch 38/50
# 6/6 - 0s - 19ms/step - loss: 0.0036
# Epoch 39/50
# 6/6 - 0s - 19ms/step - loss: 0.0036
# Epoch 40/50
# 6/6 - 0s - 18ms/step - loss: 0.0036
# Epoch 41/50
# 6/6 - 0s - 18ms/step - loss: 0.0036
# Epoch 42/50
# 6/6 - 0s - 20ms/step - loss: 0.0036
# Epoch 43/50
# 6/6 - 0s - 24ms/step - loss: 0.0036
# Epoch 44/50
# 6/6 - 0s - 24ms/step - loss: 0.0036
# Epoch 45/50
# 6/6 - 0s - 23ms/step - loss: 0.0036
# Epoch 46/50
# 6/6 - 0s - 28ms/step - loss: 0.0036
# Epoch 47/50
# 6/6 - 0s - 23ms/step - loss: 0.0036
# Epoch 48/50
# 6/6 - 0s - 21ms/step - loss: 0.0036
# Epoch 49/50
# 6/6 - 0s - 24ms/step - loss: 0.0036
# Epoch 50/50
# 6/6 - 0s - 25ms/step - loss: 0.0036
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001D9D1573100> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step
# Mean Squared Error for Rice (local): 1.5299146362276619
# Epoch 1/50
# 6/6 - 7s - 1s/step - loss: 0.3088
# Epoch 2/50
# 6/6 - 0s - 13ms/step - loss: 0.0365
# Epoch 3/50
# 6/6 - 0s - 13ms/step - loss: 0.0513
# Epoch 4/50
# 6/6 - 0s - 15ms/step - loss: 0.0173
# Epoch 5/50
# 6/6 - 0s - 16ms/step - loss: 0.0205
# Epoch 6/50
# 6/6 - 0s - 17ms/step - loss: 0.0122
# Epoch 7/50
# 6/6 - 0s - 15ms/step - loss: 0.0060
# Epoch 8/50
# 6/6 - 0s - 15ms/step - loss: 0.0091
# Epoch 9/50
# 6/6 - 0s - 15ms/step - loss: 0.0075
# Epoch 10/50
# 6/6 - 0s - 15ms/step - loss: 0.0069
# Epoch 11/50
# 6/6 - 0s - 15ms/step - loss: 0.0055
# Epoch 12/50
# 6/6 - 0s - 15ms/step - loss: 0.0054
# Epoch 13/50
# 6/6 - 0s - 15ms/step - loss: 0.0053
# Epoch 14/50
# 6/6 - 0s - 15ms/step - loss: 0.0051
# Epoch 15/50
# 6/6 - 0s - 17ms/step - loss: 0.0049
# Epoch 16/50
# 6/6 - 0s - 17ms/step - loss: 0.0048
# Epoch 17/50
# 6/6 - 0s - 19ms/step - loss: 0.0048
# Epoch 18/50
# 6/6 - 0s - 20ms/step - loss: 0.0048
# Epoch 19/50
# 6/6 - 0s - 18ms/step - loss: 0.0048
# Epoch 20/50
# 6/6 - 0s - 17ms/step - loss: 0.0047
# Epoch 21/50
# 6/6 - 0s - 16ms/step - loss: 0.0047
# Epoch 22/50
# 6/6 - 0s - 21ms/step - loss: 0.0047
# Epoch 23/50
# 6/6 - 0s - 27ms/step - loss: 0.0047
# Epoch 24/50
# 6/6 - 0s - 21ms/step - loss: 0.0047
# Epoch 25/50
# 6/6 - 0s - 20ms/step - loss: 0.0047
# Epoch 26/50
# 6/6 - 0s - 20ms/step - loss: 0.0047
# Epoch 27/50
# 6/6 - 0s - 22ms/step - loss: 0.0047
# Epoch 28/50
# 6/6 - 0s - 23ms/step - loss: 0.0047
# Epoch 29/50
# 6/6 - 0s - 21ms/step - loss: 0.0047
# Epoch 30/50
# 6/6 - 0s - 22ms/step - loss: 0.0047
# Epoch 31/50
# 6/6 - 0s - 25ms/step - loss: 0.0047
# Epoch 32/50
# 6/6 - 0s - 24ms/step - loss: 0.0047
# Epoch 33/50
# 6/6 - 0s - 20ms/step - loss: 0.0047
# Epoch 34/50
# 6/6 - 0s - 22ms/step - loss: 0.0047
# Epoch 35/50
# 6/6 - 0s - 30ms/step - loss: 0.0047
# Epoch 36/50
# 6/6 - 0s - 26ms/step - loss: 0.0047
# Epoch 37/50
# 6/6 - 0s - 46ms/step - loss: 0.0047
# Epoch 38/50
# 6/6 - 0s - 27ms/step - loss: 0.0047
# Epoch 39/50
# 6/6 - 0s - 23ms/step - loss: 0.0046
# Epoch 40/50
# 6/6 - 0s - 27ms/step - loss: 0.0046
# Epoch 41/50
# 6/6 - 0s - 26ms/step - loss: 0.0046
# Epoch 42/50
# 6/6 - 0s - 26ms/step - loss: 0.0046
# Epoch 43/50
# 6/6 - 0s - 27ms/step - loss: 0.0046
# Epoch 44/50
# 6/6 - 0s - 28ms/step - loss: 0.0046
# Epoch 45/50
# 6/6 - 0s - 28ms/step - loss: 0.0046
# Epoch 46/50
# 6/6 - 0s - 36ms/step - loss: 0.0046
# Epoch 47/50
# 6/6 - 0s - 25ms/step - loss: 0.0046
# Epoch 48/50
# 6/6 - 0s - 21ms/step - loss: 0.0046
# Epoch 49/50
# 6/6 - 0s - 22ms/step - loss: 0.0046
# Epoch 50/50
# 6/6 - 0s - 23ms/step - loss: 0.0046
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 189ms/step
# Mean Squared Error for Meat (camel): 0.41876800258175234
# Epoch 1/50
# 6/6 - 8s - 1s/step - loss: 0.2370
# Epoch 2/50
# 6/6 - 0s - 20ms/step - loss: 0.0297
# Epoch 3/50
# 6/6 - 0s - 20ms/step - loss: 0.0352
# Epoch 4/50
# 6/6 - 0s - 20ms/step - loss: 0.0143
# Epoch 5/50
# 6/6 - 0s - 21ms/step - loss: 0.0144
# Epoch 6/50
# 6/6 - 0s - 19ms/step - loss: 0.0098
# Epoch 7/50
# 6/6 - 0s - 17ms/step - loss: 0.0045
# Epoch 8/50
# 6/6 - 0s - 17ms/step - loss: 0.0066
# Epoch 9/50
# 6/6 - 0s - 17ms/step - loss: 0.0055
# Epoch 10/50
# 6/6 - 0s - 17ms/step - loss: 0.0050
# Epoch 11/50
# 6/6 - 0s - 17ms/step - loss: 0.0039
# Epoch 12/50
# 6/6 - 0s - 16ms/step - loss: 0.0038
# Epoch 13/50
# 6/6 - 0s - 16ms/step - loss: 0.0037
# Epoch 14/50
# 6/6 - 0s - 18ms/step - loss: 0.0036
# Epoch 15/50
# 6/6 - 0s - 21ms/step - loss: 0.0034
# Epoch 16/50
# 6/6 - 0s - 24ms/step - loss: 0.0034
# Epoch 17/50
# 6/6 - 0s - 25ms/step - loss: 0.0034
# Epoch 18/50
# 6/6 - 0s - 26ms/step - loss: 0.0034
# Epoch 19/50
# 6/6 - 0s - 25ms/step - loss: 0.0033
# Epoch 20/50
# 6/6 - 0s - 26ms/step - loss: 0.0033
# Epoch 21/50
# 6/6 - 0s - 26ms/step - loss: 0.0033
# Epoch 22/50
# 6/6 - 0s - 26ms/step - loss: 0.0033
# Epoch 23/50
# 6/6 - 0s - 26ms/step - loss: 0.0033
# Epoch 24/50
# 6/6 - 0s - 27ms/step - loss: 0.0033
# Epoch 25/50
# 6/6 - 0s - 25ms/step - loss: 0.0033
# Epoch 26/50
# 6/6 - 0s - 25ms/step - loss: 0.0033
# Epoch 27/50
# 6/6 - 0s - 28ms/step - loss: 0.0033
# Epoch 28/50
# 6/6 - 0s - 25ms/step - loss: 0.0033
# Epoch 29/50
# 6/6 - 0s - 22ms/step - loss: 0.0033
# Epoch 30/50
# 6/6 - 0s - 22ms/step - loss: 0.0033
# Epoch 31/50
# 6/6 - 0s - 23ms/step - loss: 0.0033
# Epoch 32/50
# 6/6 - 0s - 24ms/step - loss: 0.0033
# Epoch 33/50
# 6/6 - 0s - 31ms/step - loss: 0.0033
# Epoch 34/50
# 6/6 - 0s - 30ms/step - loss: 0.0033
# Epoch 35/50
# 6/6 - 0s - 30ms/step - loss: 0.0033
# Epoch 36/50
# 6/6 - 0s - 28ms/step - loss: 0.0033
# Epoch 37/50
# 6/6 - 0s - 29ms/step - loss: 0.0033
# Epoch 38/50
# 6/6 - 0s - 26ms/step - loss: 0.0033
# Epoch 39/50
# 6/6 - 0s - 26ms/step - loss: 0.0033
# Epoch 40/50
# 6/6 - 0s - 30ms/step - loss: 0.0033
# Epoch 41/50
# 6/6 - 0s - 28ms/step - loss: 0.0033
# Epoch 42/50
# 6/6 - 0s - 25ms/step - loss: 0.0033
# Epoch 43/50
# 6/6 - 0s - 25ms/step - loss: 0.0033
# Epoch 44/50
# 6/6 - 0s - 26ms/step - loss: 0.0033
# Epoch 45/50
# 6/6 - 0s - 23ms/step - loss: 0.0032
# Epoch 46/50
# 6/6 - 0s - 22ms/step - loss: 0.0032
# Epoch 47/50
# 6/6 - 0s - 22ms/step - loss: 0.0032
# Epoch 48/50
# 6/6 - 0s - 23ms/step - loss: 0.0032
# Epoch 49/50
# 6/6 - 0s - 23ms/step - loss: 0.0032
# Epoch 50/50
# 6/6 - 0s - 23ms/step - loss: 0.0032
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 152ms/step
# Mean Squared Error for Meat (beef): 0.29186274101450627

# %% [markdown]
# Meat (beef) et Meat (camel) : Les faibles MSE pour ces séries suggèrent que le modèle est efficace pour capturer les dynamiques des prix de la viande de bœuf et de chameau. Cela pourrait être dû à des tendances saisonnières ou des cycles de prix que le modèle a bien appris.
#
# Rice (imported) et Rice (local) :Les faibles MSE pour ces séries indique que le modèle est également performant pour prédire les prix du riz, qu'il soit importé ou local. Cela pourrait être attribué à une bonne capture des variations de prix influencées par des facteurs comme les politiques d'importation, les conditions climatiques, et la demande.

# %%
# Fonction pour tester la stationnarité
def test_stationarity(timeseries):
    result = adfuller(timeseries)
    print(f'ADF Statistic: {result[0]}')
    print(f'p-value: {result[1]}')
    return result[1]

# Convertir la colonne 'date' en datetime
df['date'] = pd.to_datetime(df['date'])

# Produits spécifiés
produits_specifies = ['Sugar', 'Oil (vegetable)', 'Rice (imported)', 'Rice (local)', 'Meat (camel)', 'Meat (beef)']

# Calculer la moyenne des prix par jour et produit
df_moyennes = df.groupby(['date', 'commodity'])['price'].mean().reset_index()

# Filtrer les données pour les produits spécifiés
df_produits = df_moyennes[df_moyennes['commodity'].isin(produits_specifies)]

# Appliquer une différenciation itérative pour rendre les séries stationnaires si nécessaire
df_stationnaire = pd.DataFrame()
for produit in produits_specifies:
    prix_produit = df_produits[df_produits['commodity'] == produit][['date', 'commodity', 'price']]
    p_value = test_stationarity(prix_produit['price'])
    
    while p_value > 0.05:
        prix_produit['price'] = prix_produit['price'].diff().dropna()
        p_value = test_stationarity(prix_produit['price'].dropna())
    
    df_stationnaire = pd.concat([df_stationnaire, prix_produit.dropna()], axis=0)

# Préparation des données pour LSTM
def prepare_data(df, produit, time_steps=10):
    df_produit = df[df['commodity'] == produit].copy()
    df_produit.set_index('date', inplace=True)
    values = df_produit['price'].values.reshape(-1, 1)
    
    # Normalisation des données
    scaler = MinMaxScaler(feature_range=(0, 1))
    values_scaled = scaler.fit_transform(values)
    
    # Création des séquences
    X, y = [], []
    for i in range(len(values_scaled) - time_steps):
        X.append(values_scaled[i:(i + time_steps), 0])
        y.append(values_scaled[i + time_steps, 0])
    
    X, y = np.array(X), np.array(y)
    X = X.reshape((X.shape[0], X.shape[1], 1))
    
    return X, y, scaler

# Construire et entraîner le modèle LSTM
def train_lstm(X, y, epochs=50, batch_size=32):
    model = Sequential()
    model.add(LSTM(50, return_sequences=True, input_shape=(X.shape[1], X.shape[2])))
    model.add(LSTM(50))
    model.add(Dense(1))
    model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')
    model.fit(X, y, epochs=epochs, batch_size=batch_size, verbose=2, shuffle=False)
    return model 

# Faire des prédictions
def predict(model, X, scaler):
    predictions = model.predict(X)
    predictions = scaler.inverse_transform(predictions)
    return predictions

# Visualiser les résultats
def plot_predictions(dates, actual, predicted, produit):
    plt.figure(figsize=(12, 6))
    plt.plot(dates, actual, color='blue', label='Actual')
    plt.plot(dates, predicted, color='red', linestyle='--', label='Predicted')
    plt.title(f'Actual vs Predicted Prices for {produit}')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

# Paramètres
time_steps = 10

for produit in produits_specifies:
    X, y, scaler = prepare_data(df_stationnaire, produit, time_steps)
    model = train_lstm(X, y, epochs=50, batch_size=32)
    
    # Faire des prédictions
    predictions = predict(model, X, scaler)
    
    # Comparer avec les données réelles
    dates = df_stationnaire[df_stationnaire['commodity'] == produit]['date'][time_steps:]
    actual_prices = df_stationnaire[df_stationnaire['commodity'] == produit]['price'][time_steps:]
    
    # Visualisation
    plot_predictions(dates, actual_prices, predictions, produit)

    # Evaluation du modèle
    mse = mean_squared_error(actual_prices, predictions)
    rmse = np.sqrt(mse)
    r2 = r2_score(actual_prices, predictions)
    print(f'Mean Squared Error for {produit}: {mse}')
    print(f'Root Mean Squared Error for {produit}: {rmse}')
    print(f'R^2 Score for {produit}: {r2}')
# Out:
# ADF Statistic: -0.9607983433362531
# p-value: 0.767292442731325
# ADF Statistic: -13.257353251636214
# p-value: 8.53460551066981e-25
# ADF Statistic: -1.5894976365253255
# p-value: 0.4888670383443275
# ADF Statistic: -8.282190648000011
# p-value: 4.4885630297663014e-13
# ADF Statistic: -0.5865086528083452
# p-value: 0.8740014704315165
# ADF Statistic: -15.967615651619832
# p-value: 7.063039069079486e-29
# ADF Statistic: 0.4616749454310371
# p-value: 0.9836604914570902
# ADF Statistic: -6.878171312458675
# p-value: 1.456359095593797e-09
# ADF Statistic: -1.4864764866446432
# p-value: 0.5401903054388553
# ADF Statistic: -15.656044333451229
# p-value: 1.5749519674396348e-28
# ADF Statistic: -1.4673441268651242
# p-value: 0.5495994771520452
# ADF Statistic: -9.616046271294818
# p-value: 1.7593159001089229e-16
# Epoch 1/50
# 6/6 - 6s - 961ms/step - loss: 0.1742
# Epoch 2/50
# 6/6 - 0s - 19ms/step - loss: 0.0265
# Epoch 3/50
# 6/6 - 0s - 16ms/step - loss: 0.0305
# Epoch 4/50
# 6/6 - 0s - 18ms/step - loss: 0.0137
# Epoch 5/50
# 6/6 - 0s - 17ms/step - loss: 0.0176
# Epoch 6/50
# 6/6 - 0s - 16ms/step - loss: 0.0131
# Epoch 7/50
# 6/6 - 0s - 17ms/step - loss: 0.0131
# Epoch 8/50
# 6/6 - 0s - 16ms/step - loss: 0.0126
# Epoch 9/50
# 6/6 - 0s - 17ms/step - loss: 0.0123
# Epoch 10/50
# 6/6 - 0s - 18ms/step - loss: 0.0123
# Epoch 11/50
# 6/6 - 0s - 18ms/step - loss: 0.0121
# Epoch 12/50
# 6/6 - 0s - 19ms/step - loss: 0.0121
# Epoch 13/50
# 6/6 - 0s - 19ms/step - loss: 0.0121
# Epoch 14/50
# 6/6 - 0s - 18ms/step - loss: 0.0121
# Epoch 15/50
# 6/6 - 0s - 19ms/step - loss: 0.0120
# Epoch 16/50
# 6/6 - 0s - 18ms/step - loss: 0.0120
# Epoch 17/50
# 6/6 - 0s - 19ms/step - loss: 0.0120
# Epoch 18/50
# 6/6 - 0s - 19ms/step - loss: 0.0120
# Epoch 19/50
# 6/6 - 0s - 17ms/step - loss: 0.0120
# Epoch 20/50
# 6/6 - 0s - 20ms/step - loss: 0.0120
# Epoch 21/50
# 6/6 - 0s - 21ms/step - loss: 0.0120
# Epoch 22/50
# 6/6 - 0s - 21ms/step - loss: 0.0120
# Epoch 23/50
# 6/6 - 0s - 21ms/step - loss: 0.0120
# Epoch 24/50
# 6/6 - 0s - 22ms/step - loss: 0.0120
# Epoch 25/50
# 6/6 - 0s - 20ms/step - loss: 0.0120
# Epoch 26/50
# 6/6 - 0s - 22ms/step - loss: 0.0120
# Epoch 27/50
# 6/6 - 0s - 21ms/step - loss: 0.0120
# Epoch 28/50
# 6/6 - 0s - 25ms/step - loss: 0.0120
# Epoch 29/50
# 6/6 - 0s - 21ms/step - loss: 0.0120
# Epoch 30/50
# 6/6 - 0s - 21ms/step - loss: 0.0120
# Epoch 31/50
# 6/6 - 0s - 22ms/step - loss: 0.0120
# Epoch 32/50
# 6/6 - 0s - 22ms/step - loss: 0.0120
# Epoch 33/50
# 6/6 - 0s - 23ms/step - loss: 0.0120
# Epoch 34/50
# 6/6 - 0s - 22ms/step - loss: 0.0120
# Epoch 35/50
# 6/6 - 0s - 21ms/step - loss: 0.0120
# Epoch 36/50
# 6/6 - 0s - 21ms/step - loss: 0.0120
# Epoch 37/50
# 6/6 - 0s - 21ms/step - loss: 0.0120
# Epoch 38/50
# 6/6 - 0s - 41ms/step - loss: 0.0119
# Epoch 39/50
# 6/6 - 0s - 27ms/step - loss: 0.0119
# Epoch 40/50
# 6/6 - 0s - 22ms/step - loss: 0.0119
# Epoch 41/50
# 6/6 - 0s - 23ms/step - loss: 0.0119
# Epoch 42/50
# 6/6 - 0s - 22ms/step - loss: 0.0119
# Epoch 43/50
# 6/6 - 0s - 22ms/step - loss: 0.0119
# Epoch 44/50
# 6/6 - 0s - 20ms/step - loss: 0.0119
# Epoch 45/50
# 6/6 - 0s - 20ms/step - loss: 0.0119
# Epoch 46/50
# 6/6 - 0s - 19ms/step - loss: 0.0119
# Epoch 47/50
# 6/6 - 0s - 19ms/step - loss: 0.0119
# Epoch 48/50
# 6/6 - 0s - 22ms/step - loss: 0.0119
# Epoch 49/50
# 6/6 - 0s - 19ms/step - loss: 0.0119
# Epoch 50/50
# 6/6 - 0s - 19ms/step - loss: 0.0119
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step
# Mean Squared Error for Sugar: 1.2497441050292688
# Root Mean Squared Error for Sugar: 1.117919543182455
# R^2 Score for Sugar: -0.011771114104821567
# Epoch 1/50
# 6/6 - 5s - 897ms/step - loss: 0.2400
# Epoch 2/50
# 6/6 - 0s - 14ms/step - loss: 0.0691
# Epoch 3/50
# 6/6 - 0s - 14ms/step - loss: 0.0194
# Epoch 4/50
# 6/6 - 0s - 16ms/step - loss: 0.0199
# Epoch 5/50
# 6/6 - 0s - 16ms/step - loss: 0.0116
# Epoch 6/50
# 6/6 - 0s - 16ms/step - loss: 0.0148
# Epoch 7/50
# 6/6 - 0s - 16ms/step - loss: 0.0115
# Epoch 8/50
# 6/6 - 0s - 15ms/step - loss: 0.0110
# Epoch 9/50
# 6/6 - 0s - 16ms/step - loss: 0.0106
# Epoch 10/50
# 6/6 - 0s - 16ms/step - loss: 0.0104
# Epoch 11/50
# 6/6 - 0s - 16ms/step - loss: 0.0107
# Epoch 12/50
# 6/6 - 0s - 15ms/step - loss: 0.0104
# Epoch 13/50
# 6/6 - 0s - 16ms/step - loss: 0.0104
# Epoch 14/50
# 6/6 - 0s - 16ms/step - loss: 0.0103
# Epoch 15/50
# 6/6 - 0s - 18ms/step - loss: 0.0104
# Epoch 16/50
# 6/6 - 0s - 18ms/step - loss: 0.0104
# Epoch 17/50
# 6/6 - 0s - 17ms/step - loss: 0.0103
# Epoch 18/50
# 6/6 - 0s - 16ms/step - loss: 0.0103
# Epoch 19/50
# 6/6 - 0s - 19ms/step - loss: 0.0104
# Epoch 20/50
# 6/6 - 0s - 19ms/step - loss: 0.0104
# Epoch 21/50
# 6/6 - 0s - 16ms/step - loss: 0.0103
# Epoch 22/50
# 6/6 - 0s - 17ms/step - loss: 0.0103
# Epoch 23/50
# 6/6 - 0s - 17ms/step - loss: 0.0103
# Epoch 24/50
# 6/6 - 0s - 18ms/step - loss: 0.0103
# Epoch 25/50
# 6/6 - 0s - 19ms/step - loss: 0.0103
# Epoch 26/50
# 6/6 - 0s - 18ms/step - loss: 0.0103
# Epoch 27/50
# 6/6 - 0s - 17ms/step - loss: 0.0103
# Epoch 28/50
# 6/6 - 0s - 17ms/step - loss: 0.0103
# Epoch 29/50
# 6/6 - 0s - 16ms/step - loss: 0.0103
# Epoch 30/50
# 6/6 - 0s - 23ms/step - loss: 0.0103
# Epoch 31/50
# 6/6 - 0s - 20ms/step - loss: 0.0103
# Epoch 32/50
# 6/6 - 0s - 18ms/step - loss: 0.0103
# Epoch 33/50
# 6/6 - 0s - 18ms/step - loss: 0.0103
# Epoch 34/50
# 6/6 - 0s - 17ms/step - loss: 0.0103
# Epoch 35/50
# 6/6 - 0s - 19ms/step - loss: 0.0103
# Epoch 36/50
# 6/6 - 0s - 17ms/step - loss: 0.0103
# Epoch 37/50
# 6/6 - 0s - 17ms/step - loss: 0.0103
# Epoch 38/50
# 6/6 - 0s - 17ms/step - loss: 0.0103
# Epoch 39/50
# 6/6 - 0s - 16ms/step - loss: 0.0103
# Epoch 40/50
# 6/6 - 0s - 16ms/step - loss: 0.0103
# Epoch 41/50
# 6/6 - 0s - 15ms/step - loss: 0.0103
# Epoch 42/50
# 6/6 - 0s - 17ms/step - loss: 0.0103
# Epoch 43/50
# 6/6 - 0s - 18ms/step - loss: 0.0103
# Epoch 44/50
# 6/6 - 0s - 16ms/step - loss: 0.0103
# Epoch 45/50
# 6/6 - 0s - 15ms/step - loss: 0.0103
# Epoch 46/50
# 6/6 - 0s - 15ms/step - loss: 0.0103
# Epoch 47/50
# 6/6 - 0s - 16ms/step - loss: 0.0103
# Epoch 48/50
# 6/6 - 0s - 16ms/step - loss: 0.0103
# Epoch 49/50
# 6/6 - 0s - 18ms/step - loss: 0.0103
# Epoch 50/50
# 6/6 - 0s - 17ms/step - loss: 0.0103
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step
# Mean Squared Error for Oil (vegetable): 4.160730270670702
# Root Mean Squared Error for Oil (vegetable): 2.039786819908076
# R^2 Score for Oil (vegetable): 0.004379868536022347
# Epoch 1/50
# 8/8 - 5s - 665ms/step - loss: 0.1511
# Epoch 2/50
# 8/8 - 0s - 13ms/step - loss: 0.0239
# Epoch 3/50
# 8/8 - 0s - 13ms/step - loss: 0.0080
# Epoch 4/50
# 8/8 - 0s - 13ms/step - loss: 0.0099
# Epoch 5/50
# 8/8 - 0s - 15ms/step - loss: 0.0059
# Epoch 6/50
# 8/8 - 0s - 13ms/step - loss: 0.0049
# Epoch 7/50
# 8/8 - 0s - 14ms/step - loss: 0.0050
# Epoch 8/50
# 8/8 - 0s - 13ms/step - loss: 0.0047
# Epoch 9/50
# 8/8 - 0s - 13ms/step - loss: 0.0046
# Epoch 10/50
# 8/8 - 0s - 15ms/step - loss: 0.0046
# Epoch 11/50
# 8/8 - 0s - 14ms/step - loss: 0.0046
# Epoch 12/50
# 8/8 - 0s - 14ms/step - loss: 0.0045
# Epoch 13/50
# 8/8 - 0s - 14ms/step - loss: 0.0045
# Epoch 14/50
# 8/8 - 0s - 14ms/step - loss: 0.0045
# Epoch 15/50
# 8/8 - 0s - 14ms/step - loss: 0.0045
# Epoch 16/50
# 8/8 - 0s - 13ms/step - loss: 0.0045
# Epoch 17/50
# 8/8 - 0s - 13ms/step - loss: 0.0045
# Epoch 18/50
# 8/8 - 0s - 14ms/step - loss: 0.0045
# Epoch 19/50
# 8/8 - 0s - 13ms/step - loss: 0.0045
# Epoch 20/50
# 8/8 - 0s - 13ms/step - loss: 0.0045
# Epoch 21/50
# 8/8 - 0s - 14ms/step - loss: 0.0045
# Epoch 22/50
# 8/8 - 0s - 13ms/step - loss: 0.0045
# Epoch 23/50
# 8/8 - 0s - 14ms/step - loss: 0.0045
# Epoch 24/50
# 8/8 - 0s - 15ms/step - loss: 0.0045
# Epoch 25/50
# 8/8 - 0s - 15ms/step - loss: 0.0045
# Epoch 26/50
# 8/8 - 0s - 14ms/step - loss: 0.0045
# Epoch 27/50
# 8/8 - 0s - 14ms/step - loss: 0.0045
# Epoch 28/50
# 8/8 - 0s - 13ms/step - loss: 0.0045
# Epoch 29/50
# 8/8 - 0s - 13ms/step - loss: 0.0045
# Epoch 30/50
# 8/8 - 0s - 13ms/step - loss: 0.0045
# Epoch 31/50
# 8/8 - 0s - 13ms/step - loss: 0.0045
# Epoch 32/50
# 8/8 - 0s - 13ms/step - loss: 0.0045
# Epoch 33/50
# 8/8 - 0s - 14ms/step - loss: 0.0045
# Epoch 34/50
# 8/8 - 0s - 13ms/step - loss: 0.0045
# Epoch 35/50
# 8/8 - 0s - 14ms/step - loss: 0.0045
# Epoch 36/50
# 8/8 - 0s - 14ms/step - loss: 0.0045
# Epoch 37/50
# 8/8 - 0s - 14ms/step - loss: 0.0045
# Epoch 38/50
# 8/8 - 0s - 15ms/step - loss: 0.0045
# Epoch 39/50
# 8/8 - 0s - 14ms/step - loss: 0.0045
# Epoch 40/50
# 8/8 - 0s - 14ms/step - loss: 0.0045
# Epoch 41/50
# 8/8 - 0s - 14ms/step - loss: 0.0045
# Epoch 42/50
# 8/8 - 0s - 13ms/step - loss: 0.0045
# Epoch 43/50
# 8/8 - 0s - 14ms/step - loss: 0.0045
# Epoch 44/50
# 8/8 - 0s - 14ms/step - loss: 0.0045
# Epoch 45/50
# 8/8 - 0s - 16ms/step - loss: 0.0045
# Epoch 46/50
# 8/8 - 0s - 14ms/step - loss: 0.0045
# Epoch 47/50
# 8/8 - 0s - 14ms/step - loss: 0.0045
# Epoch 48/50
# 8/8 - 0s - 14ms/step - loss: 0.0045
# Epoch 49/50
# 8/8 - 0s - 14ms/step - loss: 0.0045
# Epoch 50/50
# 8/8 - 0s - 13ms/step - loss: 0.0045
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 119ms/step
# Mean Squared Error for Rice (imported): 1.6983772911897956
# Root Mean Squared Error for Rice (imported): 1.3032180520503065
# R^2 Score for Rice (imported): -0.05299968229490104
# Epoch 1/50
# 6/6 - 8s - 1s/step - loss: 0.2255
# Epoch 2/50
# 6/6 - 0s - 23ms/step - loss: 0.0320
# Epoch 3/50
# 6/6 - 0s - 21ms/step - loss: 0.0326
# Epoch 4/50
# 6/6 - 0s - 18ms/step - loss: 0.0087
# Epoch 5/50
# 6/6 - 0s - 18ms/step - loss: 0.0143
# Epoch 6/50
# 6/6 - 0s - 18ms/step - loss: 0.0080
# Epoch 7/50
# 6/6 - 0s - 18ms/step - loss: 0.0080
# Epoch 8/50
# 6/6 - 0s - 19ms/step - loss: 0.0071
# Epoch 9/50
# 6/6 - 0s - 19ms/step - loss: 0.0069
# Epoch 10/50
# 6/6 - 0s - 20ms/step - loss: 0.0068
# Epoch 11/50
# 6/6 - 0s - 19ms/step - loss: 0.0066
# Epoch 12/50
# 6/6 - 0s - 19ms/step - loss: 0.0066
# Epoch 13/50
# 6/6 - 0s - 20ms/step - loss: 0.0065
# Epoch 14/50
# 6/6 - 0s - 19ms/step - loss: 0.0065
# Epoch 15/50
# 6/6 - 0s - 18ms/step - loss: 0.0065
# Epoch 16/50
# 6/6 - 0s - 20ms/step - loss: 0.0065
# Epoch 17/50
# 6/6 - 0s - 19ms/step - loss: 0.0065
# Epoch 18/50
# 6/6 - 0s - 18ms/step - loss: 0.0065
# Epoch 19/50
# 6/6 - 0s - 19ms/step - loss: 0.0065
# Epoch 20/50
# 6/6 - 0s - 19ms/step - loss: 0.0065
# Epoch 21/50
# 6/6 - 0s - 19ms/step - loss: 0.0065
# Epoch 22/50
# 6/6 - 0s - 19ms/step - loss: 0.0065
# Epoch 23/50
# 6/6 - 0s - 18ms/step - loss: 0.0065
# Epoch 24/50
# 6/6 - 0s - 19ms/step - loss: 0.0065
# Epoch 25/50
# 6/6 - 0s - 19ms/step - loss: 0.0065
# Epoch 26/50
# 6/6 - 0s - 19ms/step - loss: 0.0065
# Epoch 27/50
# 6/6 - 0s - 18ms/step - loss: 0.0065
# Epoch 28/50
# 6/6 - 0s - 18ms/step - loss: 0.0065
# Epoch 29/50
# 6/6 - 0s - 18ms/step - loss: 0.0065
# Epoch 30/50
# 6/6 - 0s - 23ms/step - loss: 0.0065
# Epoch 31/50
# 6/6 - 0s - 30ms/step - loss: 0.0065
# Epoch 32/50
# 6/6 - 0s - 26ms/step - loss: 0.0065
# Epoch 33/50
# 6/6 - 0s - 39ms/step - loss: 0.0065
# Epoch 34/50
# 6/6 - 0s - 19ms/step - loss: 0.0065
# Epoch 35/50
# 6/6 - 0s - 20ms/step - loss: 0.0065
# Epoch 36/50
# 6/6 - 0s - 20ms/step - loss: 0.0065
# Epoch 37/50
# 6/6 - 0s - 20ms/step - loss: 0.0065
# Epoch 38/50
# 6/6 - 0s - 22ms/step - loss: 0.0065
# Epoch 39/50
# 6/6 - 0s - 21ms/step - loss: 0.0065
# Epoch 40/50
# 6/6 - 0s - 21ms/step - loss: 0.0065
# Epoch 41/50
# 6/6 - 0s - 21ms/step - loss: 0.0065
# Epoch 42/50
# 6/6 - 0s - 25ms/step - loss: 0.0065
# Epoch 43/50
# 6/6 - 0s - 25ms/step - loss: 0.0065
# Epoch 44/50
# 6/6 - 0s - 29ms/step - loss: 0.0065
# Epoch 45/50
# 6/6 - 0s - 26ms/step - loss: 0.0065
# Epoch 46/50
# 6/6 - 0s - 27ms/step - loss: 0.0065
# Epoch 47/50
# 6/6 - 0s - 25ms/step - loss: 0.0065
# Epoch 48/50
# 6/6 - 0s - 23ms/step - loss: 0.0065
# Epoch 49/50
# 6/6 - 0s - 24ms/step - loss: 0.0065
# Epoch 50/50
# 6/6 - 0s - 23ms/step - loss: 0.0065
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 143ms/step
# Mean Squared Error for Rice (local): 1.7624246544910946
# Root Mean Squared Error for Rice (local): 1.3275634276715726
# R^2 Score for Rice (local): -0.030475790358633015
# Epoch 1/50
# 6/6 - 6s - 1s/step - loss: 0.3578
# Epoch 2/50
# 6/6 - 0s - 13ms/step - loss: 0.1062
# Epoch 3/50
# 6/6 - 0s - 13ms/step - loss: 0.0265
# Epoch 4/50
# 6/6 - 0s - 14ms/step - loss: 0.0219
# Epoch 5/50
# 6/6 - 0s - 14ms/step - loss: 0.0129
# Epoch 6/50
# 6/6 - 0s - 14ms/step - loss: 0.0144
# Epoch 7/50
# 6/6 - 0s - 14ms/step - loss: 0.0083
# Epoch 8/50
# 6/6 - 0s - 14ms/step - loss: 0.0096
# Epoch 9/50
# 6/6 - 0s - 14ms/step - loss: 0.0079
# Epoch 10/50
# 6/6 - 0s - 15ms/step - loss: 0.0082
# Epoch 11/50
# 6/6 - 0s - 15ms/step - loss: 0.0078
# Epoch 12/50
# 6/6 - 0s - 16ms/step - loss: 0.0078
# Epoch 13/50
# 6/6 - 0s - 15ms/step - loss: 0.0077
# Epoch 14/50
# 6/6 - 0s - 16ms/step - loss: 0.0077
# Epoch 15/50
# 6/6 - 0s - 15ms/step - loss: 0.0077
# Epoch 16/50
# 6/6 - 0s - 15ms/step - loss: 0.0077
# Epoch 17/50
# 6/6 - 0s - 15ms/step - loss: 0.0077
# Epoch 18/50
# 6/6 - 0s - 16ms/step - loss: 0.0077
# Epoch 19/50
# 6/6 - 0s - 16ms/step - loss: 0.0077
# Epoch 20/50
# 6/6 - 0s - 15ms/step - loss: 0.0077
# Epoch 21/50
# 6/6 - 0s - 15ms/step - loss: 0.0076
# Epoch 22/50
# 6/6 - 0s - 15ms/step - loss: 0.0076
# Epoch 23/50
# 6/6 - 0s - 15ms/step - loss: 0.0076
# Epoch 24/50
# 6/6 - 0s - 15ms/step - loss: 0.0076
# Epoch 25/50
# 6/6 - 0s - 16ms/step - loss: 0.0076
# Epoch 26/50
# 6/6 - 0s - 16ms/step - loss: 0.0076
# Epoch 27/50
# 6/6 - 0s - 15ms/step - loss: 0.0076
# Epoch 28/50
# 6/6 - 0s - 13ms/step - loss: 0.0076
# Epoch 29/50
# 6/6 - 0s - 16ms/step - loss: 0.0076
# Epoch 30/50
# 6/6 - 0s - 15ms/step - loss: 0.0076
# Epoch 31/50
# 6/6 - 0s - 16ms/step - loss: 0.0076
# Epoch 32/50
# 6/6 - 0s - 15ms/step - loss: 0.0076
# Epoch 33/50
# 6/6 - 0s - 15ms/step - loss: 0.0076
# Epoch 34/50
# 6/6 - 0s - 15ms/step - loss: 0.0076
# Epoch 35/50
# 6/6 - 0s - 15ms/step - loss: 0.0076
# Epoch 36/50
# 6/6 - 0s - 16ms/step - loss: 0.0076
# Epoch 37/50
# 6/6 - 0s - 15ms/step - loss: 0.0076
# Epoch 38/50
# 6/6 - 0s - 15ms/step - loss: 0.0076
# Epoch 39/50
# 6/6 - 0s - 15ms/step - loss: 0.0076
# Epoch 40/50
# 6/6 - 0s - 16ms/step - loss: 0.0076
# Epoch 41/50
# 6/6 - 0s - 22ms/step - loss: 0.0076
# Epoch 42/50
# 6/6 - 0s - 18ms/step - loss: 0.0076
# Epoch 43/50
# 6/6 - 0s - 16ms/step - loss: 0.0076
# Epoch 44/50
# 6/6 - 0s - 16ms/step - loss: 0.0076
# Epoch 45/50
# 6/6 - 0s - 16ms/step - loss: 0.0076
# Epoch 46/50
# 6/6 - 0s - 16ms/step - loss: 0.0076
# Epoch 47/50
# 6/6 - 0s - 15ms/step - loss: 0.0076
# Epoch 48/50
# 6/6 - 0s - 16ms/step - loss: 0.0076
# Epoch 49/50
# 6/6 - 0s - 15ms/step - loss: 0.0076
# Epoch 50/50
# 6/6 - 0s - 15ms/step - loss: 0.0076
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step
# Mean Squared Error for Meat (camel): 0.14402036741328406
# Root Mean Squared Error for Meat (camel): 0.37950015469467735
# R^2 Score for Meat (camel): -0.042537946704798824
# Epoch 1/50
# 6/6 - 6s - 988ms/step - loss: 0.3185
# Epoch 2/50
# 6/6 - 0s - 15ms/step - loss: 0.0459
# Epoch 3/50
# 6/6 - 0s - 15ms/step - loss: 0.0467
# Epoch 4/50
# 6/6 - 0s - 15ms/step - loss: 0.0144
# Epoch 5/50
# 6/6 - 0s - 15ms/step - loss: 0.0211
# Epoch 6/50
# 6/6 - 0s - 16ms/step - loss: 0.0145
# Epoch 7/50
# 6/6 - 0s - 14ms/step - loss: 0.0127
# Epoch 8/50
# 6/6 - 0s - 17ms/step - loss: 0.0127
# Epoch 9/50
# 6/6 - 0s - 19ms/step - loss: 0.0116
# Epoch 10/50
# 6/6 - 0s - 19ms/step - loss: 0.0118
# Epoch 11/50
# 6/6 - 0s - 19ms/step - loss: 0.0114
# Epoch 12/50
# 6/6 - 0s - 19ms/step - loss: 0.0115
# Epoch 13/50
# 6/6 - 0s - 20ms/step - loss: 0.0114
# Epoch 14/50
# 6/6 - 0s - 16ms/step - loss: 0.0114
# Epoch 15/50
# 6/6 - 0s - 16ms/step - loss: 0.0114
# Epoch 16/50
# 6/6 - 0s - 15ms/step - loss: 0.0114
# Epoch 17/50
# 6/6 - 0s - 16ms/step - loss: 0.0114
# Epoch 18/50
# 6/6 - 0s - 16ms/step - loss: 0.0114
# Epoch 19/50
# 6/6 - 0s - 16ms/step - loss: 0.0114
# Epoch 20/50
# 6/6 - 0s - 16ms/step - loss: 0.0114
# Epoch 21/50
# 6/6 - 0s - 15ms/step - loss: 0.0114
# Epoch 22/50
# 6/6 - 0s - 15ms/step - loss: 0.0113
# Epoch 23/50
# 6/6 - 0s - 15ms/step - loss: 0.0113
# Epoch 24/50
# 6/6 - 0s - 15ms/step - loss: 0.0113
# Epoch 25/50
# 6/6 - 0s - 16ms/step - loss: 0.0113
# Epoch 26/50
# 6/6 - 0s - 15ms/step - loss: 0.0113
# Epoch 27/50
# 6/6 - 0s - 15ms/step - loss: 0.0113
# Epoch 28/50
# 6/6 - 0s - 15ms/step - loss: 0.0113
# Epoch 29/50
# 6/6 - 0s - 15ms/step - loss: 0.0113
# Epoch 30/50
# 6/6 - 0s - 15ms/step - loss: 0.0113
# Epoch 31/50
# 6/6 - 0s - 15ms/step - loss: 0.0113
# Epoch 32/50
# 6/6 - 0s - 15ms/step - loss: 0.0113
# Epoch 33/50
# 6/6 - 0s - 15ms/step - loss: 0.0113
# Epoch 34/50
# 6/6 - 0s - 15ms/step - loss: 0.0113
# Epoch 35/50
# 6/6 - 0s - 15ms/step - loss: 0.0113
# Epoch 36/50
# 6/6 - 0s - 15ms/step - loss: 0.0113
# Epoch 37/50
# 6/6 - 0s - 15ms/step - loss: 0.0113
# Epoch 38/50
# 6/6 - 0s - 15ms/step - loss: 0.0113
# Epoch 39/50
# 6/6 - 0s - 14ms/step - loss: 0.0113
# Epoch 40/50
# 6/6 - 0s - 15ms/step - loss: 0.0113
# Epoch 41/50
# 6/6 - 0s - 15ms/step - loss: 0.0113
# Epoch 42/50
# 6/6 - 0s - 15ms/step - loss: 0.0113
# Epoch 43/50
# 6/6 - 0s - 15ms/step - loss: 0.0113
# Epoch 44/50
# 6/6 - 0s - 15ms/step - loss: 0.0113
# Epoch 45/50
# 6/6 - 0s - 15ms/step - loss: 0.0113
# Epoch 46/50
# 6/6 - 0s - 15ms/step - loss: 0.0113
# Epoch 47/50
# 6/6 - 0s - 15ms/step - loss: 0.0113
# Epoch 48/50
# 6/6 - 0s - 15ms/step - loss: 0.0113
# Epoch 49/50
# 6/6 - 0s - 15ms/step - loss: 0.0113
# Epoch 50/50
# 6/6 - 0s - 15ms/step - loss: 0.0113
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step
# Mean Squared Error for Meat (beef): 0.1116676108028369
# Root Mean Squared Error for Meat (beef): 0.3341670402700375
# R^2 Score for Meat (beef): -0.05466361879850168

# %% [markdown]
# <div style="background-color: #d1e7f2; padding: 20px; border-radius: 10px;">
#     <font color="navy">
#         <span style="font-family: 'Times New Roman'; font-size: 16pt;">
#             <b>VI. &nbsp;&nbsp;&nbsp;  Prévisions des prix :</b>
#         </span>
#     </font>
# </div>

# %%
# Fonction pour prédire le prix futur pour une date donnée
def predict_future_price(produit, future_date, df_produits, time_steps=10):
    future_date = pd.to_datetime(future_date)
    
    # Préparer les données pour le produit
    X, y, scaler = prepare_data(df_produits, produit, time_steps)
    model = train_lstm(X, y, epochs=50, batch_size=32)

    # Calculer le nombre de jours à prédire
    last_date = df_produits[df_produits['commodity'] == produit]['date'].max()
    days_to_predict = (future_date - last_date).days
    
    if days_to_predict <= 0:
        raise ValueError("Future date must be after the last date in the dataset.")
    
    # Utiliser la dernière séquence pour prédire plusieurs jours dans le futur
    last_sequence = X[-1].reshape((1, time_steps, 1))
    
    for _ in range(days_to_predict):
        future_price_scaled = model.predict(last_sequence)
        last_sequence = np.append(last_sequence[:, 1:, :], future_price_scaled.reshape(1, 1, 1), axis=1)

    future_price = scaler.inverse_transform(future_price_scaled)
    return future_price[0][0]

# Exemple d'utilisation de la fonction pour une date future
produit = 'Sugar'
future_date = '2024-01-01'
predicted_price = predict_future_price(produit, future_date, df_produits)

print(f'Predicted future price for {produit} on {future_date}: {predicted_price}')
# Out:
# Epoch 1/50
# 6/6 - 5s - 828ms/step - loss: 0.1047
# Epoch 2/50
# 6/6 - 0s - 22ms/step - loss: 0.0176
# Epoch 3/50
# 6/6 - 0s - 19ms/step - loss: 0.0200
# Epoch 4/50
# 6/6 - 0s - 14ms/step - loss: 0.0121
# Epoch 5/50
# 6/6 - 0s - 25ms/step - loss: 0.0101
# Epoch 6/50
# 6/6 - 0s - 20ms/step - loss: 0.0083
# Epoch 7/50
# 6/6 - 0s - 14ms/step - loss: 0.0103
# Epoch 8/50
# 6/6 - 0s - 11ms/step - loss: 0.0088
# Epoch 9/50
# 6/6 - 0s - 19ms/step - loss: 0.0081
# Epoch 10/50
# 6/6 - 0s - 14ms/step - loss: 0.0079
# Epoch 11/50
# 6/6 - 0s - 19ms/step - loss: 0.0082
# Epoch 12/50
# 6/6 - 0s - 20ms/step - loss: 0.0079
# Epoch 13/50
# 6/6 - 0s - 17ms/step - loss: 0.0076
# Epoch 14/50
# 6/6 - 0s - 22ms/step - loss: 0.0077
# Epoch 15/50
# 6/6 - 0s - 12ms/step - loss: 0.0077
# Epoch 16/50
# 6/6 - 0s - 11ms/step - loss: 0.0075
# Epoch 17/50
# 6/6 - 0s - 17ms/step - loss: 0.0075
# Epoch 18/50
# 6/6 - 0s - 16ms/step - loss: 0.0075
# Epoch 19/50
# 6/6 - 0s - 20ms/step - loss: 0.0074
# Epoch 20/50
# 6/6 - 0s - 14ms/step - loss: 0.0073
# Epoch 21/50
# 6/6 - 0s - 17ms/step - loss: 0.0073
# Epoch 22/50
# 6/6 - 0s - 19ms/step - loss: 0.0072
# Epoch 23/50
# 6/6 - 0s - 19ms/step - loss: 0.0072
# Epoch 24/50
# 6/6 - 0s - 19ms/step - loss: 0.0071
# Epoch 25/50
# 6/6 - 0s - 20ms/step - loss: 0.0071
# Epoch 26/50
# 6/6 - 0s - 20ms/step - loss: 0.0070
# Epoch 27/50
# 6/6 - 0s - 16ms/step - loss: 0.0069
# Epoch 28/50
# 6/6 - 0s - 19ms/step - loss: 0.0069
# Epoch 29/50
# 6/6 - 0s - 19ms/step - loss: 0.0068
# Epoch 30/50
# 6/6 - 0s - 21ms/step - loss: 0.0067
# Epoch 31/50
# 6/6 - 0s - 18ms/step - loss: 0.0067
# Epoch 32/50
# 6/6 - 0s - 20ms/step - loss: 0.0066
# Epoch 33/50
# 6/6 - 0s - 22ms/step - loss: 0.0066
# Epoch 34/50
# 6/6 - 0s - 17ms/step - loss: 0.0065
# Epoch 35/50
# 6/6 - 0s - 20ms/step - loss: 0.0064
# Epoch 36/50
# 6/6 - 0s - 19ms/step - loss: 0.0063
# Epoch 37/50
# 6/6 - 0s - 17ms/step - loss: 0.0063
# Epoch 38/50
# 6/6 - 0s - 22ms/step - loss: 0.0062
# Epoch 39/50
# 6/6 - 0s - 25ms/step - loss: 0.0061
# Epoch 40/50
# 6/6 - 0s - 20ms/step - loss: 0.0061
# Epoch 41/50
# 6/6 - 0s - 28ms/step - loss: 0.0060
# Epoch 42/50
# 6/6 - 0s - 18ms/step - loss: 0.0059
# Epoch 43/50
# 6/6 - 0s - 19ms/step - loss: 0.0058
# Epoch 44/50
# 6/6 - 0s - 17ms/step - loss: 0.0058
# Epoch 45/50
# 6/6 - 0s - 18ms/step - loss: 0.0057
# Epoch 46/50
# 6/6 - 0s - 21ms/step - loss: 0.0056
# Epoch 47/50
# 6/6 - 0s - 17ms/step - loss: 0.0055
# Epoch 48/50
# 6/6 - 0s - 25ms/step - loss: 0.0055
# Epoch 49/50
# 6/6 - 0s - 19ms/step - loss: 0.0054
# Epoch 50/50
# 6/6 - 0s - 17ms/step - loss: 0.0053
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 534ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Predicted future price for Sugar on 2024-01-01: 40.82426834106445

# %% [markdown]
# <div style="background-color: #d1e7f2; padding: 20px; border-radius: 10px;">
#     <font color="navy">
#         <span style="font-family: 'Times New Roman'; font-size: 16pt;">
#             <b>VII. &nbsp;&nbsp;&nbsp;  Recommandations  :</b>
#         </span>
#     </font>
# </div>

# %% [markdown]
# 1. *Mise en Place d'un Observatoire des Prix* : Établir un système national de surveillance des prix des denrées alimentaires pour détecter rapidement les fluctuations et les tendances. Cela permettrait de réagir promptement aux changements du marché.
#
# 2. *Promotion de l'Agriculture Locale* : Encourager la production locale de denrées alimentaires pour réduire la dépendance aux importations et stabiliser les prix.
#
# 3. *Accords Commerciaux Stratégiques* : Négocier des accords commerciaux avec des pays partenaires pour diversifier les sources d'importation et atténuer les impacts des fluctuations du marché international.
#
# 4. *Investissement dans les Transports* : Améliorer les infrastructures de transport pour faciliter l'acheminement des produits alimentaires des zones de production aux marchés urbains et ruraux.
#
# 5. *Programmes de Sensibilisation* : Développer des campagnes de sensibilisation pour informer les agriculteurs et les commerçants sur les meilleures pratiques agricoles et commerciales.
#
# 6. *Formation Continue* : Offrir des programmes de formation continue aux parties prenantes du secteur agricole et alimentaire pour améliorer leurs compétences en gestion et en adaptation aux changements du marché.
